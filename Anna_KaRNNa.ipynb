# %% [markdown]
# # Anna KaRNNa
#
# In this notebook, we'll build a character-wise RNN trained on Anna Karenina, one of my all-time favorite books. It'll be able to generate new text based on the text from the book.
#
# This network is based off of Andrej Karpathy's [post on RNNs](http://karpathy.github.io/2015/05/21/rnn-effectiveness/) and [implementation in Torch](https://github.com/karpathy/char-rnn). Also, some information [here at r2rt](http://r2rt.com/recurrent-neural-networks-in-tensorflow-ii.html) and from [Sherjil Ozair](https://github.com/sherjilozair/char-rnn-tensorflow) on GitHub. Below is the general architecture of the character-wise RNN.
#
# <img src="assets/charseq.jpeg" width="500">

# %%
import time
from collections import namedtuple

import numpy as np
import tensorflow as tf

# %% [markdown]
# First we'll load the text file and convert it into integers for our network to use. Here I'm creating a couple dictionaries to convert the characters to and from integers. Encoding the characters as integers makes it easier to use as input in the network.

# %%
with open('anna.txt', 'r') as f:
    text=f.read()
vocab = sorted(set(text))
vocab_to_int = {c: i for i, c in enumerate(vocab)}
int_to_vocab = dict(enumerate(vocab))
encoded = np.array([vocab_to_int[c] for c in text], dtype=np.int32)

# %% [markdown]
# Let's check out the first 100 characters, make sure everything is peachy. According to the [American Book Review](http://americanbookreview.org/100bestlines.asp), this is the 6th best first line of a book ever.

# %%
text[:100]
# Out:
# 'Chapter 1\n\n\nHappy families are all alike; every unhappy family is unhappy in its own\nway.\n\nEverythin'

# %% [markdown]
# And we can see the characters encoded as integers.

# %%
encoded[:100]
# Out:
# array([31, 64, 57, 72, 76, 61, 74,  1, 16,  0,  0,  0, 36, 57, 72, 72, 81,
#         1, 62, 57, 69, 65, 68, 65, 61, 75,  1, 57, 74, 61,  1, 57, 68, 68,
#         1, 57, 68, 65, 67, 61, 26,  1, 61, 78, 61, 74, 81,  1, 77, 70, 64,
#        57, 72, 72, 81,  1, 62, 57, 69, 65, 68, 81,  1, 65, 75,  1, 77, 70,
#        64, 57, 72, 72, 81,  1, 65, 70,  1, 65, 76, 75,  1, 71, 79, 70,  0,
#        79, 57, 81, 13,  0,  0, 33, 78, 61, 74, 81, 76, 64, 65, 70],
#       dtype=int32)

# %% [markdown]
# Since the network is working with individual characters, it's similar to a classification problem in which we are trying to predict the next character from the previous text.  Here's how many 'classes' our network has to pick from.

# %%
len(vocab)
# Out:
# 83

# %% [markdown]
# ## Making training mini-batches
#
# Here is where we'll make our mini-batches for training. Remember that we want our batches to be multiple sequences of some desired number of sequence steps. Considering a simple example, our batches would look like this:
#
# <img src="assets/sequence_batching@1x.png" width=500px>
#
#
# <br>
#
# We start with our text encoded as integers in one long array in `encoded`. Let's create a function that will give us an iterator for our batches. I like using [generator functions](https://jeffknupp.com/blog/2013/04/07/improve-your-python-yield-and-generators-explained/) to do this. Then we can pass `encoded` into this function and get our batch generator.
#
# The first thing we need to do is discard some of the text so we only have completely full batches. Each batch contains $N \times M$ characters, where $N$ is the batch size (the number of sequences) and $M$ is the number of steps. Then, to get the total number of batches, $K$, we can make from the array `arr`, you divide the length of `arr` by the number of characters per batch. Once you know the number of batches, you can get the total number of characters to keep from `arr`, $N * M * K$.
#
# After that, we need to split `arr` into $N$ sequences. You can do this using `arr.reshape(size)` where `size` is a tuple containing the dimensions sizes of the reshaped array. We know we want $N$ sequences (`batch_size` below), let's make that the size of the first dimension. For the second dimension, you can use `-1` as a placeholder in the size, it'll fill up the array with the appropriate data for you. After this, you should have an array that is $N \times (M * K)$.
#
# Now that we have this array, we can iterate through it to get our batches. The idea is each batch is a $N \times M$ window on the $N \times (M * K)$ array. For each subsequent batch, the window moves over by `n_steps`. We also want to create both the input and target arrays. Remember that the targets are the inputs shifted over one character.
#
# The way I like to do this window is use `range` to take steps of size `n_steps` from $0$ to `arr.shape[1]`, the total number of steps in each sequence. That way, the integers you get from `range` always point to the start of a batch, and each window is `n_steps` wide.
#
# > **Exercise:** Write the code for creating batches in the function below. The exercises in this notebook _will not be easy_. I've provided a notebook with solutions alongside this notebook. If you get stuck, checkout the solutions. The most important thing is that you don't copy and paste the code into here, **type out the solution code yourself.**

# %%
def get_batches(arr, batch_size, n_steps):
    '''Create a generator that returns batches of size
       batch_size x n_steps from arr.
       
       Arguments
       ---------
       arr: Array you want to make batches from
       batch_size: Batch size, the number of sequences per batch
       n_steps: Number of sequence steps per batch
    '''
    # Get the number of characters per batch and number of batches we can make
    chars_per_batch = batch_size * n_steps
    n_batches = len(arr) // chars_per_batch
    
    # Keep only enough characters to make full batches
    arr = arr[:n_batches * chars_per_batch]
    
    # Reshape into batch_size rows
    arr = arr.reshape((batch_size, -1))
    
    for n in range(0, arr.shape[1], n_steps):
        # The features
        x = arr[:, n:n+n_steps]
        # The targets, shifted by one
        y_temp = arr[:, n + 1:n + n_steps + 1]
        
        # For the very last batch, y will be one character short at the end of 
        # the sequences which breaks things. To get around this, I'll make an 
        # array of the appropriate size first, of all zeros, then add the targets.
        # This will introduce a small artifact in the last batch, but it won't matter.
        y = np.zeros(x.shape, dtype=x.dtype)
        y[:, :y_temp.shape[1]] = y_temp
        
        yield x, y

# %% [markdown]
# Now I'll make my data sets and we can check out what's going on here. Here I'm going to use a batch size of 10 and 50 sequence steps.

# %%
batches = get_batches(encoded, 10, 50)
x, y = next(batches)

# %%
print('x\n', x[:10, :10])
print('\ny\n', y[:10, :10])
# Out:
# x
#  [[31 64 57 72 76 61 74  1 16  0]
#  [ 1 57 69  1 70 71 76  1 63 71]
#  [78 65 70 13  0  0  3 53 61 75]
#  [70  1 60 77 74 65 70 63  1 64]
#  [ 1 65 76  1 65 75 11  1 75 65]
#  [ 1 37 76  1 79 57 75  0 71 70]
#  [64 61 70  1 59 71 69 61  1 62]
#  [26  1 58 77 76  1 70 71 79  1]
#  [76  1 65 75 70  7 76 13  1 48]
#  [ 1 75 57 65 60  1 76 71  1 64]]
#
# y
#  [[64 57 72 76 61 74  1 16  0  0]
#  [57 69  1 70 71 76  1 63 71 65]
#  [65 70 13  0  0  3 53 61 75 11]
#  [ 1 60 77 74 65 70 63  1 64 65]
#  [65 76  1 65 75 11  1 75 65 74]
#  [37 76  1 79 57 75  0 71 70 68]
#  [61 70  1 59 71 69 61  1 62 71]
#  [ 1 58 77 76  1 70 71 79  1 75]
#  [ 1 65 75 70  7 76 13  1 48 64]
#  [75 57 65 60  1 76 71  1 64 61]]

# %% [markdown]
# If you implemented `get_batches` correctly, the above output should look something like
# ```
# x
#  [[55 63 69 22  6 76 45  5 16 35]
#  [ 5 69  1  5 12 52  6  5 56 52]
#  [48 29 12 61 35 35  8 64 76 78]
#  [12  5 24 39 45 29 12 56  5 63]
#  [ 5 29  6  5 29 78 28  5 78 29]
#  [ 5 13  6  5 36 69 78 35 52 12]
#  [63 76 12  5 18 52  1 76  5 58]
#  [34  5 73 39  6  5 12 52 36  5]
#  [ 6  5 29 78 12 79  6 61  5 59]
#  [ 5 78 69 29 24  5  6 52  5 63]]
#
# y
#  [[63 69 22  6 76 45  5 16 35 35]
#  [69  1  5 12 52  6  5 56 52 29]
#  [29 12 61 35 35  8 64 76 78 28]
#  [ 5 24 39 45 29 12 56  5 63 29]
#  [29  6  5 29 78 28  5 78 29 45]
#  [13  6  5 36 69 78 35 52 12 43]
#  [76 12  5 18 52  1 76  5 58 52]
#  [ 5 73 39  6  5 12 52 36  5 78]
#  [ 5 29 78 12 79  6 61  5 59 63]
#  [78 69 29 24  5  6 52  5 63 76]]
#  ```
#  although the exact numbers will be different. Check to make sure the data is shifted over one step for `y`.

# %% [markdown]
# ## Building the model
#
# Below is where you'll build the network. We'll break it up into parts so it's easier to reason about each bit. Then we can connect them up into the whole network.
#
# <img src="assets/charRNN.png" width=500px>
#
#
# ### Inputs
#
# First off we'll create our input placeholders. As usual we need placeholders for the training data and the targets. We'll also create a placeholder for dropout layers called `keep_prob`. This will be a scalar, that is a 0-D tensor. To make a scalar, you create a placeholder without giving it a size.
#
# > **Exercise:** Create the input placeholders in the function below.

# %%
def build_inputs(batch_size, num_steps):
    ''' Define placeholders for inputs, targets, and dropout 
    
        Arguments
        ---------
        batch_size: Batch size, number of sequences per batch
        num_steps: Number of sequence steps in a batch
        
    '''
    # Declare placeholders we'll feed into the graph
    inputs = tf.placeholder(tf.int32, [batch_size, num_steps], 
                            name='inputs')
    targets = tf.placeholder(tf.int32, [batch_size, num_steps], 
                            name='targets')
    
    # Keep probability placeholder for drop out layers
    keep_prob = tf.placeholder(tf.float32, name='keep_prob')
    
    return inputs, targets, keep_prob

# %% [markdown]
# ### LSTM Cell
#
# Here we will create the LSTM cell we'll use in the hidden layer. We'll use this cell as a building block for the RNN. So we aren't actually defining the RNN here, just the type of cell we'll use in the hidden layer.
#
# We first create a basic LSTM cell with
#
# ```python
# lstm = tf.contrib.rnn.BasicLSTMCell(num_units)
# ```
#
# where `num_units` is the number of units in the hidden layers in the cell. Then we can add dropout by wrapping it with
#
# ```python
# tf.contrib.rnn.DropoutWrapper(lstm, output_keep_prob=keep_prob)
# ```
# You pass in a cell and it will automatically add dropout to the inputs or outputs. Finally, we can stack up the LSTM cells into layers with [`tf.contrib.rnn.MultiRNNCell`](https://www.tensorflow.org/versions/r1.0/api_docs/python/tf/contrib/rnn/MultiRNNCell). With this, you pass in a list of cells and it will send the output of one cell into the next cell. Previously with TensorFlow 1.0, you could do this
#
# ```python
# tf.contrib.rnn.MultiRNNCell([cell]*num_layers)
# ```
#
# This might look a little weird if you know Python well because this will create a list of the same `cell` object. However, TensorFlow 1.0 will create different weight matrices for all `cell` objects. But, starting with TensorFlow 1.1 you actually need to create new cell objects in the list. To get it to work in TensorFlow 1.1, it should look like
#
# ```python
# def build_cell(num_units, keep_prob):
#     lstm = tf.contrib.rnn.BasicLSTMCell(num_units)
#     drop = tf.contrib.rnn.DropoutWrapper(lstm, output_keep_prob=keep_prob)
#
#     return drop
#
# tf.contrib.rnn.MultiRNNCell([build_cell(num_units, keep_prob) for _ in range(num_layers)])
# ```
#
# Even though this is actually multiple LSTM cells stacked on each other, you can treat the multiple layers as one cell.
#
# We also need to create an initial cell state of all zeros. This can be done like so
#
# ```python
# initial_state = cell.zero_state(batch_size, tf.float32)
# ```
#
# Below, we implement the `build_lstm` function to create these LSTM cells and the initial state.

# %%
def build_lstm(lstm_size, num_layers, batch_size, keep_prob):
    ''' Build LSTM cell.
    
        Arguments
        ---------
        keep_prob: Scalar tensor (tf.placeholder) for the dropout keep probability
        lstm_size: Size of the hidden layers in the LSTM cells
        num_layers: Number of LSTM layers
        batch_size: Batch size

    '''
    ### Build the LSTM Cell
    def build_cell(lstm_size, keep_prob):
        # Use a basic LSTM cell
        lstm = tf.contrib.rnn.BasicLSTMCell(lstm_size)
        
        # Add dropout to the cell outputs
        drop = tf.contrib.rnn.DropoutWrapper(lstm, output_keep_prob=keep_prob)
        return drop
    
    # Stack up multiple LSTM layers, for deep learning
    cell = tf.contrib.rnn.MultiRNNCell([build_cell(lstm_size, keep_prob) for _ in range(num_layers)])
    initial_state = cell.zero_state(batch_size, tf.float32)
    
    return cell, initial_state

# %% [markdown]
# ### RNN Output
#
# Here we'll create the output layer. We need to connect the output of the RNN cells to a full connected layer with a softmax output. The softmax output gives us a probability distribution we can use to predict the next character, so we want this layer to have size $C$, the number of classes/characters we have in our text.
#
# If our input has batch size $N$, number of steps $M$, and the hidden layer has $L$ hidden units, then the output is a 3D tensor with size $N \times M \times L$. The output of each LSTM cell has size $L$, we have $M$ of them, one for each sequence step, and we have $N$ sequences. So the total size is $N \times M \times L$.
#
# We are using the same fully connected layer, the same weights, for each of the outputs. Then, to make things easier, we should reshape the outputs into a 2D tensor with shape $(M * N) \times L$. That is, one row for each sequence and step, where the values of each row are the output from the LSTM cells. We get the LSTM output as a list, `lstm_output`. First we need to concatenate this whole list into one array with [`tf.concat`](https://www.tensorflow.org/api_docs/python/tf/concat). Then, reshape it (with `tf.reshape`) to size $(M * N) \times L$.
#
# One we have the outputs reshaped, we can do the matrix multiplication with the weights. We need to wrap the weight and bias variables in a variable scope with `tf.variable_scope(scope_name)` because there are weights being created in the LSTM cells. TensorFlow will throw an error if the weights created here have the same names as the weights created in the LSTM cells, which they will be default. To avoid this, we wrap the variables in a variable scope so we can give them unique names.
#
# > **Exercise:** Implement the output layer in the function below.

# %%
def build_output(lstm_output, in_size, out_size):
    ''' Build a softmax layer, return the softmax output and logits.
    
        Arguments
        ---------
        
        lstm_output: List of output tensors from the LSTM layer
        in_size: Size of the input tensor, for example, size of the LSTM cells
        out_size: Size of this softmax layer
    
    '''

    # Reshape output so it's a bunch of rows, one row for each step for 
    # each sequence. Concatenate lstm_output over axis 1 (the columns)
    seq_output = tf.concat(lstm_output, axis=1)
    # Reshape seq_output to a 2D tensor with lstm_size columns
    x = tf.reshape(seq_output, [-1, lstm_size])
    
    # Connect the RNN outputs to a softmax layer
    with tf.variable_scope('softmax'):
        # Create the weight and bias variables here
        softmax_w = tf.Variable(tf.truncated_normal((in_size, out_size), 
                                                    stddev=0.1))
        softmax_b = tf.Variable(tf.zeros(out_size))
    
    # Since output is a bunch of rows of RNN cell outputs, logits will 
    # be a bunch of rows of logit outputs, one for each step and 
    # sequence
    logits = tf.matmul(x, softmax_w) + softmax_b
    
    # Use softmax to get the probabilities for predicted characters
    out = tf.nn.softmax(logits, name='predictions')
    
    return out, logits

# %% [markdown]
# ### Training loss
#
# Next up is the training loss. We get the logits and targets and calculate the softmax cross-entropy loss. First we need to one-hot encode the targets, we're getting them as encoded characters. Then, reshape the one-hot targets so it's a 2D tensor with size $(M*N) \times C$ where $C$ is the number of classes/characters we have. Remember that we reshaped the LSTM outputs and ran them through a fully connected layer with $C$ units. So our logits will also have size $(M*N) \times C$.
#
# Then we run the logits and targets through `tf.nn.softmax_cross_entropy_with_logits` and find the mean to get the loss.
#
# >**Exercise:** Implement the loss calculation in the function below.

# %%
def build_loss(logits, targets, lstm_size, num_classes):
    ''' Calculate the loss from the logits and the targets.
    
        Arguments
        ---------
        logits: Logits from final fully connected layer
        targets: Targets for supervised learning
        lstm_size: Number of LSTM hidden units
        num_classes: Number of classes in targets
        
    '''
    
    # One-hot encode targets and reshape to match logits, one row per 
    # sequence per step
    y_one_hot = tf.one_hot(targets, num_classes)
    y_reshaped = tf.reshape(y_one_hot, logits.get_shape())
    
    # Softmax cross entropy loss
    loss = tf.nn.softmax_cross_entropy_with_logits_v2(logits=logits, 
                                                      labels=y_reshaped)
    loss = tf.reduce_mean(loss)
    
    return loss

# %% [markdown]
# ### Optimizer
#
# Here we build the optimizer. Normal RNNs have have issues gradients exploding and disappearing. LSTMs fix the disappearance problem, but the gradients can still grow without bound. To fix this, we can clip the gradients above some threshold. That is, if a gradient is larger than that threshold, we set it to the threshold. This will ensure the gradients never grow overly large. Then we use an AdamOptimizer for the learning step.

# %%
def build_optimizer(loss, learning_rate, grad_clip):
    ''' Build optmizer for training, using gradient clipping.
    
        Arguments:
        loss: Network loss
        learning_rate: Learning rate for optimizer
    
    '''
    
    # Optimizer for training, using gradient clipping to control 
    # exploding gradients
    tvars = tf.trainable_variables()
    grads, _ = tf.clip_by_global_norm(tf.gradients(loss, tvars), 
                                      grad_clip)
    train_op = tf.train.AdamOptimizer(learning_rate)
    optimizer = train_op.apply_gradients(zip(grads, tvars))
    
    return optimizer

# %% [markdown]
# ### Build the network
#
# Now we can put all the pieces together and build a class for the network. To actually run data through the LSTM cells, we will use [`tf.nn.dynamic_rnn`](https://www.tensorflow.org/versions/r1.0/api_docs/python/tf/nn/dynamic_rnn). This function will pass the hidden and cell states across LSTM cells appropriately for us. It returns the outputs for each LSTM cell at each step for each sequence in the mini-batch. It also gives us the final LSTM state. We want to save this state as `final_state` so we can pass it to the first LSTM cell in the the next mini-batch run. For `tf.nn.dynamic_rnn`, we pass in the cell and initial state we get from `build_lstm`, as well as our input sequences. Also, we need to one-hot encode the inputs before going into the RNN.
#
# > **Exercise:** Use the functions you've implemented previously and `tf.nn.dynamic_rnn` to build the network.

# %%
class CharRNN:
    
    def __init__(self, num_classes, batch_size=64, num_steps=50, 
                 lstm_size=128, num_layers=2, learning_rate=0.001, 
                 grad_clip=5, sampling=False):
    
        # When we're using this network for sampling later, we'll be 
        # passing in one character at a time, so providing an option 
        # for that
        if sampling == True:
            batch_size, num_steps = 1, 1
        else:
            batch_size, num_steps = batch_size, num_steps

        tf.reset_default_graph()
        
        # Build the input placeholder tensors
        self.inputs, self.targets, self.keep_prob = build_inputs(batch_size, num_steps)

        # Build the LSTM cell
        cell, self.initial_state = build_lstm(lstm_size, num_layers, batch_size, self.keep_prob)

        ### Run the data through the RNN layers
        # First, one-hot encode the input tokens
        x_one_hot = tf.one_hot(self.inputs, num_classes)
        
        # Run each sequence step through the RNN with tf.nn.dynamic_rnn
        outputs, state = tf.nn.dynamic_rnn(cell, x_one_hot, initial_state=self.initial_state)
        self.final_state = state
        
        # Get softmax predictions and logits
        self.prediction, self.logits = build_output(outputs, lstm_size, num_classes)
        
        # Loss and optimizer (with gradient clipping)
        self.loss = build_loss(self.logits, self.targets, lstm_size, num_classes)
        self.optimizer = build_optimizer(self.loss, learning_rate, grad_clip)

# %% [markdown]
# ## Hyperparameters
#
# Here are the hyperparameters for the network.
#
# * `batch_size` - Number of sequences running through the network in one pass.
# * `num_steps` - Number of characters in the sequence the network is trained on. Larger is better typically, the network will learn more long range dependencies. But it takes longer to train. 100 is typically a good number here.
# * `lstm_size` - The number of units in the hidden layers.
# * `num_layers` - Number of hidden LSTM layers to use
# * `learning_rate` - Learning rate for training
# * `keep_prob` - The dropout keep probability when training. If you're network is overfitting, try decreasing this.
#
# Here's some good advice from Andrej Karpathy on training the network. I'm going to copy it in here for your benefit, but also link to [where it originally came from](https://github.com/karpathy/char-rnn#tips-and-tricks).
#
# > ## Tips and Tricks
#
# >### Monitoring Validation Loss vs. Training Loss
# >If you're somewhat new to Machine Learning or Neural Networks it can take a bit of expertise to get good models. The most important quantity to keep track of is the difference between your training loss (printed during training) and the validation loss (printed once in a while when the RNN is run on the validation data (by default every 1000 iterations)). In particular:
#
# > - If your training loss is much lower than validation loss then this means the network might be **overfitting**. Solutions to this are to decrease your network size, or to increase dropout. For example you could try dropout of 0.5 and so on.
# > - If your training/validation loss are about equal then your model is **underfitting**. Increase the size of your model (either number of layers or the raw number of neurons per layer)
#
# > ### Approximate number of parameters
#
# > The two most important parameters that control the model are `lstm_size` and `num_layers`. I would advise that you always use `num_layers` of either 2/3. The `lstm_size` can be adjusted based on how much data you have. The two important quantities to keep track of here are:
#
# > - The number of parameters in your model. This is printed when you start training.
# > - The size of your dataset. 1MB file is approximately 1 million characters.
#
# >These two should be about the same order of magnitude. It's a little tricky to tell. Here are some examples:
#
# > - I have a 100MB dataset and I'm using the default parameter settings (which currently print 150K parameters). My data size is significantly larger (100 mil >> 0.15 mil), so I expect to heavily underfit. I am thinking I can comfortably afford to make `lstm_size` larger.
# > - I have a 10MB dataset and running a 10 million parameter model. I'm slightly nervous and I'm carefully monitoring my validation loss. If it's larger than my training loss then I may want to try to increase dropout a bit and see if that helps the validation loss.
#
# > ### Best models strategy
#
# >The winning strategy to obtaining very good models (if you have the compute time) is to always err on making the network larger (as large as you're willing to wait for it to compute) and then try different dropout values (between 0,1). Whatever model has the best validation performance (the loss, written in the checkpoint filename, low is good) is the one you should use in the end.
#
# >It is very common in deep learning to run many different models with many different hyperparameter settings, and in the end take whatever checkpoint gave the best validation performance.
#
# >By the way, the size of your training and validation splits are also parameters. Make sure you have a decent amount of data in your validation set or otherwise the validation performance will be noisy and not very informative.

# %%
batch_size = 20         # Sequences per batch
num_steps = 100          # Number of sequence steps per batch
lstm_size = 512         # Size of hidden layers in LSTMs
num_layers = 2          # Number of LSTM layers
learning_rate = 0.01    # Learning rate
keep_prob = 0.5         # Dropout keep probability

# %% [markdown]
# ## Time for training
#
# This is typical training code, passing inputs and targets into the network, then running the optimizer. Here we also get back the final LSTM state for the mini-batch. Then, we pass that state back into the network so the next batch can continue the state from the previous batch. And every so often (set by `save_every_n`) I save a checkpoint.
#
# Here I'm saving checkpoints with the format
#
# `i{iteration number}_l{# hidden layer units}.ckpt`
#
# > **Exercise:** Set the hyperparameters above to train the network. Watch the training loss, it should be consistently dropping. Also, I highly advise running this on a GPU.

# %%
epochs = 20
# Print losses every N interations
print_every_n = 50

# Save every N iterations
save_every_n = 200

model = CharRNN(len(vocab), batch_size=batch_size, num_steps=num_steps,
                lstm_size=lstm_size, num_layers=num_layers, 
                learning_rate=learning_rate)

saver = tf.train.Saver(max_to_keep=100)
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    
    # Use the line below to load a checkpoint and resume training
    #saver.restore(sess, 'checkpoints/______.ckpt')
    counter = 0
    for e in range(epochs):
        # Train network
        new_state = sess.run(model.initial_state)
        loss = 0
        for x, y in get_batches(encoded, batch_size, num_steps):
            counter += 1
            start = time.time()
            feed = {model.inputs: x,
                    model.targets: y,
                    model.keep_prob: keep_prob,
                    model.initial_state: new_state}
            batch_loss, new_state, _ = sess.run([model.loss, 
                                                 model.final_state, 
                                                 model.optimizer], 
                                                 feed_dict=feed)
            if (counter % print_every_n == 0):
                end = time.time()
                print('Epoch: {}/{}... '.format(e+1, epochs),
                      'Training Step: {}... '.format(counter),
                      'Training loss: {:.4f}... '.format(batch_loss),
                      '{:.4f} sec/batch'.format((end-start)))
        
            if (counter % save_every_n == 0):
                saver.save(sess, "checkpoints/i{}_l{}.ckpt".format(counter, lstm_size))
    
    saver.save(sess, "checkpoints/i{}_l{}.ckpt".format(counter, lstm_size))
# Out:
# Epoch: 1/20...  Training Step: 50...  Training loss: 3.1419...  0.1357 sec/batch
# Epoch: 1/20...  Training Step: 100...  Training loss: 3.1491...  0.1371 sec/batch
# Epoch: 1/20...  Training Step: 150...  Training loss: 3.1821...  0.1403 sec/batch
# Epoch: 1/20...  Training Step: 200...  Training loss: 2.9875...  0.1365 sec/batch
# Epoch: 1/20...  Training Step: 250...  Training loss: 2.8875...  0.1379 sec/batch
# Epoch: 1/20...  Training Step: 300...  Training loss: 2.9077...  0.1466 sec/batch
# Epoch: 1/20...  Training Step: 350...  Training loss: 2.7980...  0.1383 sec/batch
# Epoch: 1/20...  Training Step: 400...  Training loss: 2.6314...  0.1360 sec/batch
# Epoch: 1/20...  Training Step: 450...  Training loss: 2.5792...  0.1384 sec/batch
# Epoch: 1/20...  Training Step: 500...  Training loss: 2.4816...  0.1376 sec/batch
# Epoch: 1/20...  Training Step: 550...  Training loss: 2.3781...  0.1360 sec/batch
# Epoch: 1/20...  Training Step: 600...  Training loss: 2.2984...  0.1375 sec/batch
# Epoch: 1/20...  Training Step: 650...  Training loss: 2.1295...  0.1383 sec/batch
# Epoch: 1/20...  Training Step: 700...  Training loss: 2.1209...  0.1374 sec/batch
# Epoch: 1/20...  Training Step: 750...  Training loss: 1.9610...  0.1366 sec/batch
# Epoch: 1/20...  Training Step: 800...  Training loss: 1.9004...  0.1385 sec/batch
# Epoch: 1/20...  Training Step: 850...  Training loss: 1.8864...  0.1359 sec/batch
# Epoch: 1/20...  Training Step: 900...  Training loss: 1.8407...  0.1376 sec/batch
# Epoch: 1/20...  Training Step: 950...  Training loss: 1.7964...  0.1370 sec/batch
# Epoch: 2/20...  Training Step: 1000...  Training loss: 1.8029...  0.1377 sec/batch
# Epoch: 2/20...  Training Step: 1050...  Training loss: 1.7803...  0.1382 sec/batch
# Epoch: 2/20...  Training Step: 1100...  Training loss: 1.7657...  0.1373 sec/batch
# Epoch: 2/20...  Training Step: 1150...  Training loss: 1.7076...  0.1374 sec/batch
# Epoch: 2/20...  Training Step: 1200...  Training loss: 1.6484...  0.1364 sec/batch
# Epoch: 2/20...  Training Step: 1250...  Training loss: 1.6625...  0.1373 sec/batch
# Epoch: 2/20...  Training Step: 1300...  Training loss: 1.5550...  0.1370 sec/batch
# Epoch: 2/20...  Training Step: 1350...  Training loss: 1.6777...  0.1369 sec/batch
# Epoch: 2/20...  Training Step: 1400...  Training loss: 1.6894...  0.1372 sec/batch
# Epoch: 2/20...  Training Step: 1450...  Training loss: 1.5678...  0.1371 sec/batch
# Epoch: 2/20...  Training Step: 1500...  Training loss: 1.5749...  0.1377 sec/batch
# Epoch: 2/20...  Training Step: 1550...  Training loss: 1.5794...  0.1366 sec/batch
# Epoch: 2/20...  Training Step: 1600...  Training loss: 1.6327...  0.1367 sec/batch
# Epoch: 2/20...  Training Step: 1650...  Training loss: 1.5270...  0.1381 sec/batch
# Epoch: 2/20...  Training Step: 1700...  Training loss: 1.5647...  0.1375 sec/batch
# Epoch: 2/20...  Training Step: 1750...  Training loss: 1.6063...  0.1359 sec/batch
# Epoch: 2/20...  Training Step: 1800...  Training loss: 1.5777...  0.1369 sec/batch
# Epoch: 2/20...  Training Step: 1850...  Training loss: 1.5390...  0.1377 sec/batch
# Epoch: 2/20...  Training Step: 1900...  Training loss: 1.5584...  0.1375 sec/batch
# Epoch: 2/20...  Training Step: 1950...  Training loss: 1.5818...  0.1360 sec/batch
# Epoch: 3/20...  Training Step: 2000...  Training loss: 1.4701...  0.1362 sec/batch
# Epoch: 3/20...  Training Step: 2050...  Training loss: 1.4809...  0.1373 sec/batch
# Epoch: 3/20...  Training Step: 2100...  Training loss: 1.6346...  0.1377 sec/batch
# Epoch: 3/20...  Training Step: 2150...  Training loss: 1.5720...  0.1363 sec/batch
# Epoch: 3/20...  Training Step: 2200...  Training loss: 1.5025...  0.1372 sec/batch
# Epoch: 3/20...  Training Step: 2250...  Training loss: 1.4268...  0.1366 sec/batch
# Epoch: 3/20...  Training Step: 2300...  Training loss: 1.4269...  0.1359 sec/batch
# Epoch: 3/20...  Training Step: 2350...  Training loss: 1.4756...  0.1364 sec/batch
# Epoch: 3/20...  Training Step: 2400...  Training loss: 1.5149...  0.1363 sec/batch
# Epoch: 3/20...  Training Step: 2450...  Training loss: 1.4476...  0.1371 sec/batch
# Epoch: 3/20...  Training Step: 2500...  Training loss: 1.4487...  0.1381 sec/batch
# Epoch: 3/20...  Training Step: 2550...  Training loss: 1.4620...  0.1368 sec/batch
# Epoch: 3/20...  Training Step: 2600...  Training loss: 1.4433...  0.1373 sec/batch
# Epoch: 3/20...  Training Step: 2650...  Training loss: 1.3901...  0.1359 sec/batch
# Epoch: 3/20...  Training Step: 2700...  Training loss: 1.4833...  0.1359 sec/batch
# Epoch: 3/20...  Training Step: 2750...  Training loss: 1.4474...  0.1371 sec/batch
# Epoch: 3/20...  Training Step: 2800...  Training loss: 1.5408...  0.1370 sec/batch
# Epoch: 3/20...  Training Step: 2850...  Training loss: 1.4238...  0.1378 sec/batch
# Epoch: 3/20...  Training Step: 2900...  Training loss: 1.4481...  0.1388 sec/batch
# Epoch: 3/20...  Training Step: 2950...  Training loss: 1.5516...  0.1355 sec/batch
# Epoch: 4/20...  Training Step: 3000...  Training loss: 1.3413...  0.1363 sec/batch
# Epoch: 4/20...  Training Step: 3050...  Training loss: 1.3754...  0.1365 sec/batch
# Epoch: 4/20...  Training Step: 3100...  Training loss: 1.3973...  0.1376 sec/batch
# Epoch: 4/20...  Training Step: 3150...  Training loss: 1.4464...  0.1360 sec/batch
# Epoch: 4/20...  Training Step: 3200...  Training loss: 1.3963...  0.1376 sec/batch
# Epoch: 4/20...  Training Step: 3250...  Training loss: 1.3581...  0.1376 sec/batch
# Epoch: 4/20...  Training Step: 3300...  Training loss: 1.3645...  0.1378 sec/batch
# Epoch: 4/20...  Training Step: 3350...  Training loss: 1.3073...  0.1378 sec/batch
# Epoch: 4/20...  Training Step: 3400...  Training loss: 1.3751...  0.1381 sec/batch
# Epoch: 4/20...  Training Step: 3450...  Training loss: 1.3924...  0.1369 sec/batch
# Epoch: 4/20...  Training Step: 3500...  Training loss: 1.3876...  0.1363 sec/batch
# Epoch: 4/20...  Training Step: 3550...  Training loss: 1.4418...  0.1371 sec/batch
# Epoch: 4/20...  Training Step: 3600...  Training loss: 1.3855...  0.1364 sec/batch
# Epoch: 4/20...  Training Step: 3650...  Training loss: 1.3953...  0.1362 sec/batch
# Epoch: 4/20...  Training Step: 3700...  Training loss: 1.4073...  0.1375 sec/batch
# Epoch: 4/20...  Training Step: 3750...  Training loss: 1.4073...  0.1367 sec/batch
# Epoch: 4/20...  Training Step: 3800...  Training loss: 1.3734...  0.1361 sec/batch
# Epoch: 4/20...  Training Step: 3850...  Training loss: 1.4162...  0.1367 sec/batch
# Epoch: 4/20...  Training Step: 3900...  Training loss: 1.3759...  0.1377 sec/batch
# Epoch: 4/20...  Training Step: 3950...  Training loss: 1.3695...  0.1382 sec/batch
# Epoch: 5/20...  Training Step: 4000...  Training loss: 1.4286...  0.1364 sec/batch
# Epoch: 5/20...  Training Step: 4050...  Training loss: 1.3260...  0.1369 sec/batch
# Epoch: 5/20...  Training Step: 4100...  Training loss: 1.4112...  0.1383 sec/batch
# Epoch: 5/20...  Training Step: 4150...  Training loss: 1.4635...  0.1367 sec/batch
# Epoch: 5/20...  Training Step: 4200...  Training loss: 1.3471...  0.1373 sec/batch
# Epoch: 5/20...  Training Step: 4250...  Training loss: 1.3109...  0.1366 sec/batch
# Epoch: 5/20...  Training Step: 4300...  Training loss: 1.3138...  0.1368 sec/batch
# Epoch: 5/20...  Training Step: 4350...  Training loss: 1.3194...  0.1392 sec/batch
# Epoch: 5/20...  Training Step: 4400...  Training loss: 1.4027...  0.1368 sec/batch
# Epoch: 5/20...  Training Step: 4450...  Training loss: 1.3387...  0.1378 sec/batch
# Epoch: 5/20...  Training Step: 4500...  Training loss: 1.3776...  0.1368 sec/batch
# Epoch: 5/20...  Training Step: 4550...  Training loss: 1.3045...  0.1379 sec/batch
# Epoch: 5/20...  Training Step: 4600...  Training loss: 1.3181...  0.1366 sec/batch
# Epoch: 5/20...  Training Step: 4650...  Training loss: 1.3826...  0.1381 sec/batch
# Epoch: 5/20...  Training Step: 4700...  Training loss: 1.3813...  0.1365 sec/batch
# Epoch: 5/20...  Training Step: 4750...  Training loss: 1.3635...  0.1370 sec/batch
# Epoch: 5/20...  Training Step: 4800...  Training loss: 1.4366...  0.1373 sec/batch
# Epoch: 5/20...  Training Step: 4850...  Training loss: 1.2747...  0.1364 sec/batch
# Epoch: 5/20...  Training Step: 4900...  Training loss: 1.4383...  0.1369 sec/batch
# Epoch: 5/20...  Training Step: 4950...  Training loss: 1.4250...  0.1356 sec/batch
# Epoch: 6/20...  Training Step: 5000...  Training loss: 1.3187...  0.1359 sec/batch
# Epoch: 6/20...  Training Step: 5050...  Training loss: 1.4251...  0.1378 sec/batch
# Epoch: 6/20...  Training Step: 5100...  Training loss: 1.3538...  0.1440 sec/batch
# Epoch: 6/20...  Training Step: 5150...  Training loss: 1.4011...  0.1383 sec/batch
# Epoch: 6/20...  Training Step: 5200...  Training loss: 1.3362...  0.1394 sec/batch
# Epoch: 6/20...  Training Step: 5250...  Training loss: 1.3206...  0.1385 sec/batch
# Epoch: 6/20...  Training Step: 5300...  Training loss: 1.3060...  0.1340 sec/batch
# Epoch: 6/20...  Training Step: 5350...  Training loss: 1.3073...  0.1368 sec/batch
# Epoch: 6/20...  Training Step: 5400...  Training loss: 1.3909...  0.1382 sec/batch
# Epoch: 6/20...  Training Step: 5450...  Training loss: 1.2684...  0.1384 sec/batch
# Epoch: 6/20...  Training Step: 5500...  Training loss: 1.3229...  0.1360 sec/batch
# Epoch: 6/20...  Training Step: 5550...  Training loss: 1.2925...  0.1364 sec/batch
# Epoch: 6/20...  Training Step: 5600...  Training loss: 1.4095...  0.1377 sec/batch
# Epoch: 6/20...  Training Step: 5650...  Training loss: 1.3781...  0.1336 sec/batch
# Epoch: 6/20...  Training Step: 5700...  Training loss: 1.3439...  0.1366 sec/batch
# Epoch: 6/20...  Training Step: 5750...  Training loss: 1.3552...  0.1381 sec/batch
# Epoch: 6/20...  Training Step: 5800...  Training loss: 1.3391...  0.1371 sec/batch
# Epoch: 6/20...  Training Step: 5850...  Training loss: 1.4111...  0.1362 sec/batch
# Epoch: 6/20...  Training Step: 5900...  Training loss: 1.4470...  0.1367 sec/batch
# Epoch: 6/20...  Training Step: 5950...  Training loss: 1.2532...  0.1367 sec/batch
# Epoch: 7/20...  Training Step: 6000...  Training loss: 1.2875...  0.1338 sec/batch
# Epoch: 7/20...  Training Step: 6050...  Training loss: 1.2784...  0.1380 sec/batch
# Epoch: 7/20...  Training Step: 6100...  Training loss: 1.2844...  0.1362 sec/batch
# Epoch: 7/20...  Training Step: 6150...  Training loss: 1.3385...  0.1374 sec/batch
# Epoch: 7/20...  Training Step: 6200...  Training loss: 1.2117...  0.1366 sec/batch
# Epoch: 7/20...  Training Step: 6250...  Training loss: 1.3907...  0.1372 sec/batch
# Epoch: 7/20...  Training Step: 6300...  Training loss: 1.3733...  0.1357 sec/batch
# Epoch: 7/20...  Training Step: 6350...  Training loss: 1.3857...  0.1345 sec/batch
# Epoch: 7/20...  Training Step: 6400...  Training loss: 1.3284...  0.1384 sec/batch
# Epoch: 7/20...  Training Step: 6450...  Training loss: 1.3341...  0.1385 sec/batch
# Epoch: 7/20...  Training Step: 6500...  Training loss: 1.3092...  0.1366 sec/batch
# Epoch: 7/20...  Training Step: 6550...  Training loss: 1.1796...  0.1369 sec/batch
# Epoch: 7/20...  Training Step: 6600...  Training loss: 1.2308...  0.1359 sec/batch
# Epoch: 7/20...  Training Step: 6650...  Training loss: 1.3294...  0.1381 sec/batch
# Epoch: 7/20...  Training Step: 6700...  Training loss: 1.2841...  0.1386 sec/batch
# Epoch: 7/20...  Training Step: 6750...  Training loss: 1.2824...  0.1382 sec/batch
# Epoch: 7/20...  Training Step: 6800...  Training loss: 1.3047...  0.1368 sec/batch
# Epoch: 7/20...  Training Step: 6850...  Training loss: 1.3407...  0.1360 sec/batch
# Epoch: 7/20...  Training Step: 6900...  Training loss: 1.2853...  0.1369 sec/batch
# Epoch: 8/20...  Training Step: 6950...  Training loss: 1.1964...  0.1384 sec/batch
# Epoch: 8/20...  Training Step: 7000...  Training loss: 1.2560...  0.1395 sec/batch
# Epoch: 8/20...  Training Step: 7050...  Training loss: 1.3314...  0.1370 sec/batch
# Epoch: 8/20...  Training Step: 7100...  Training loss: 1.2819...  0.1360 sec/batch
# Epoch: 8/20...  Training Step: 7150...  Training loss: 1.3765...  0.1377 sec/batch
# Epoch: 8/20...  Training Step: 7200...  Training loss: 1.3145...  0.1376 sec/batch
# Epoch: 8/20...  Training Step: 7250...  Training loss: 1.3422...  0.1378 sec/batch
# Epoch: 8/20...  Training Step: 7300...  Training loss: 1.3069...  0.1377 sec/batch
# Epoch: 8/20...  Training Step: 7350...  Training loss: 1.3000...  0.1393 sec/batch
# Epoch: 8/20...  Training Step: 7400...  Training loss: 1.3037...  0.1361 sec/batch
# Epoch: 8/20...  Training Step: 7450...  Training loss: 1.2039...  0.1362 sec/batch
# Epoch: 8/20...  Training Step: 7500...  Training loss: 1.2747...  0.1372 sec/batch
# Epoch: 8/20...  Training Step: 7550...  Training loss: 1.2757...  0.1363 sec/batch
# Epoch: 8/20...  Training Step: 7600...  Training loss: 1.3392...  0.1383 sec/batch
# Epoch: 8/20...  Training Step: 7650...  Training loss: 1.2378...  0.1382 sec/batch
# Epoch: 8/20...  Training Step: 7700...  Training loss: 1.3042...  0.1365 sec/batch
# Epoch: 8/20...  Training Step: 7750...  Training loss: 1.3060...  0.1372 sec/batch
# Epoch: 8/20...  Training Step: 7800...  Training loss: 1.2736...  0.1380 sec/batch
# Epoch: 8/20...  Training Step: 7850...  Training loss: 1.3392...  0.1370 sec/batch
# Epoch: 8/20...  Training Step: 7900...  Training loss: 1.3418...  0.1372 sec/batch
# Epoch: 9/20...  Training Step: 7950...  Training loss: 1.3013...  0.1369 sec/batch
# Epoch: 9/20...  Training Step: 8000...  Training loss: 1.2458...  0.1369 sec/batch
# Epoch: 9/20...  Training Step: 8050...  Training loss: 1.3176...  0.1384 sec/batch
# Epoch: 9/20...  Training Step: 8100...  Training loss: 1.3371...  0.1380 sec/batch
# Epoch: 9/20...  Training Step: 8150...  Training loss: 1.3470...  0.1372 sec/batch
# Epoch: 9/20...  Training Step: 8200...  Training loss: 1.2954...  0.1376 sec/batch
# Epoch: 9/20...  Training Step: 8250...  Training loss: 1.2489...  0.1364 sec/batch
# Epoch: 9/20...  Training Step: 8300...  Training loss: 1.2952...  0.1396 sec/batch
# Epoch: 9/20...  Training Step: 8350...  Training loss: 1.2092...  0.1375 sec/batch
# Epoch: 9/20...  Training Step: 8400...  Training loss: 1.2926...  0.1371 sec/batch
# Epoch: 9/20...  Training Step: 8450...  Training loss: 1.3647...  0.1381 sec/batch
# Epoch: 9/20...  Training Step: 8500...  Training loss: 1.2556...  0.1384 sec/batch
# Epoch: 9/20...  Training Step: 8550...  Training loss: 1.2352...  0.1369 sec/batch
# Epoch: 9/20...  Training Step: 8600...  Training loss: 1.3699...  0.1384 sec/batch
# Epoch: 9/20...  Training Step: 8650...  Training loss: 1.2803...  0.1376 sec/batch
# Epoch: 9/20...  Training Step: 8700...  Training loss: 1.3085...  0.1367 sec/batch
# Epoch: 9/20...  Training Step: 8750...  Training loss: 1.3662...  0.1381 sec/batch
# Epoch: 9/20...  Training Step: 8800...  Training loss: 1.2776...  0.1379 sec/batch
# Epoch: 9/20...  Training Step: 8850...  Training loss: 1.3134...  0.1375 sec/batch
# Epoch: 9/20...  Training Step: 8900...  Training loss: 1.2743...  0.1364 sec/batch
# Epoch: 10/20...  Training Step: 8950...  Training loss: 1.2423...  0.1381 sec/batch
# Epoch: 10/20...  Training Step: 9000...  Training loss: 1.3676...  0.1384 sec/batch
# Epoch: 10/20...  Training Step: 9050...  Training loss: 1.2695...  0.1370 sec/batch
# Epoch: 10/20...  Training Step: 9100...  Training loss: 1.2773...  0.1373 sec/batch
# Epoch: 10/20...  Training Step: 9150...  Training loss: 1.3962...  0.1372 sec/batch
# Epoch: 10/20...  Training Step: 9200...  Training loss: 1.2781...  0.1434 sec/batch
# Epoch: 10/20...  Training Step: 9250...  Training loss: 1.2041...  0.1384 sec/batch
# Epoch: 10/20...  Training Step: 9300...  Training loss: 1.2167...  0.1367 sec/batch
# Epoch: 10/20...  Training Step: 9350...  Training loss: 1.2620...  0.1372 sec/batch
# Epoch: 10/20...  Training Step: 9400...  Training loss: 1.2888...  0.1379 sec/batch
# Epoch: 10/20...  Training Step: 9450...  Training loss: 1.2504...  0.1376 sec/batch
# Epoch: 10/20...  Training Step: 9500...  Training loss: 1.2299...  0.1367 sec/batch
# Epoch: 10/20...  Training Step: 9550...  Training loss: 1.2150...  0.1374 sec/batch
# Epoch: 10/20...  Training Step: 9600...  Training loss: 1.3430...  0.1379 sec/batch
# Epoch: 10/20...  Training Step: 9650...  Training loss: 1.2855...  0.1370 sec/batch
# Epoch: 10/20...  Training Step: 9700...  Training loss: 1.3386...  0.1367 sec/batch
# Epoch: 10/20...  Training Step: 9750...  Training loss: 1.2212...  0.1359 sec/batch
# Epoch: 10/20...  Training Step: 9800...  Training loss: 1.3157...  0.1363 sec/batch
# Epoch: 10/20...  Training Step: 9850...  Training loss: 1.2878...  0.1367 sec/batch
# Epoch: 10/20...  Training Step: 9900...  Training loss: 1.3621...  0.1377 sec/batch
# Epoch: 11/20...  Training Step: 9950...  Training loss: 1.3060...  0.1368 sec/batch
# Epoch: 11/20...  Training Step: 10000...  Training loss: 1.3099...  0.1384 sec/batch
# Epoch: 11/20...  Training Step: 10050...  Training loss: 1.2818...  0.1371 sec/batch
# Epoch: 11/20...  Training Step: 10100...  Training loss: 1.2715...  0.1452 sec/batch
# Epoch: 11/20...  Training Step: 10150...  Training loss: 1.2045...  0.1375 sec/batch
# Epoch: 11/20...  Training Step: 10200...  Training loss: 1.3321...  0.1369 sec/batch
# Epoch: 11/20...  Training Step: 10250...  Training loss: 1.2847...  0.1384 sec/batch
# Epoch: 11/20...  Training Step: 10300...  Training loss: 1.3145...  0.1382 sec/batch
# Epoch: 11/20...  Training Step: 10350...  Training loss: 1.3608...  0.1345 sec/batch
# Epoch: 11/20...  Training Step: 10400...  Training loss: 1.2236...  0.1383 sec/batch
# Epoch: 11/20...  Training Step: 10450...  Training loss: 1.3127...  0.1353 sec/batch
# Epoch: 11/20...  Training Step: 10500...  Training loss: 1.1992...  0.1385 sec/batch
# Epoch: 11/20...  Training Step: 10550...  Training loss: 1.2254...  0.1384 sec/batch
# Epoch: 11/20...  Training Step: 10600...  Training loss: 1.3341...  0.1379 sec/batch
# Epoch: 11/20...  Training Step: 10650...  Training loss: 1.2504...  0.1357 sec/batch
# Epoch: 11/20...  Training Step: 10700...  Training loss: 1.2391...  0.1346 sec/batch
# Epoch: 11/20...  Training Step: 10750...  Training loss: 1.2304...  0.1379 sec/batch
# Epoch: 11/20...  Training Step: 10800...  Training loss: 1.2582...  0.1379 sec/batch
# Epoch: 11/20...  Training Step: 10850...  Training loss: 1.3168...  0.1392 sec/batch
# Epoch: 11/20...  Training Step: 10900...  Training loss: 1.2600...  0.1358 sec/batch
# Epoch: 12/20...  Training Step: 10950...  Training loss: 1.3324...  0.1397 sec/batch
# Epoch: 12/20...  Training Step: 11000...  Training loss: 1.2725...  0.1372 sec/batch
# Epoch: 12/20...  Training Step: 11050...  Training loss: 1.3503...  0.1360 sec/batch
# Epoch: 12/20...  Training Step: 11100...  Training loss: 1.2649...  0.1362 sec/batch
# Epoch: 12/20...  Training Step: 11150...  Training loss: 1.3035...  0.1384 sec/batch
# Epoch: 12/20...  Training Step: 11200...  Training loss: 1.2158...  0.1379 sec/batch
# Epoch: 12/20...  Training Step: 11250...  Training loss: 1.2619...  0.1373 sec/batch
# Epoch: 12/20...  Training Step: 11300...  Training loss: 1.3115...  0.1383 sec/batch
# Epoch: 12/20...  Training Step: 11350...  Training loss: 1.3672...  0.1383 sec/batch
# Epoch: 12/20...  Training Step: 11400...  Training loss: 1.2552...  0.1370 sec/batch
# Epoch: 12/20...  Training Step: 11450...  Training loss: 1.2316...  0.1383 sec/batch
# Epoch: 12/20...  Training Step: 11500...  Training loss: 1.2930...  0.1385 sec/batch
# Epoch: 12/20...  Training Step: 11550...  Training loss: 1.2190...  0.1374 sec/batch
# Epoch: 12/20...  Training Step: 11600...  Training loss: 1.2671...  0.1363 sec/batch
# Epoch: 12/20...  Training Step: 11650...  Training loss: 1.3213...  0.1370 sec/batch
# Epoch: 12/20...  Training Step: 11700...  Training loss: 1.2504...  0.1377 sec/batch
# Epoch: 12/20...  Training Step: 11750...  Training loss: 1.2794...  0.1365 sec/batch
# Epoch: 12/20...  Training Step: 11800...  Training loss: 1.3011...  0.1359 sec/batch
# Epoch: 12/20...  Training Step: 11850...  Training loss: 1.2653...  0.1391 sec/batch
# Epoch: 12/20...  Training Step: 11900...  Training loss: 1.2556...  0.1369 sec/batch
# Epoch: 13/20...  Training Step: 11950...  Training loss: 1.2442...  0.1381 sec/batch
# Epoch: 13/20...  Training Step: 12000...  Training loss: 1.2919...  0.1376 sec/batch
# Epoch: 13/20...  Training Step: 12050...  Training loss: 1.2832...  0.1352 sec/batch
# Epoch: 13/20...  Training Step: 12100...  Training loss: 1.2310...  0.1370 sec/batch
# Epoch: 13/20...  Training Step: 12150...  Training loss: 1.2646...  0.1377 sec/batch
# Epoch: 13/20...  Training Step: 12200...  Training loss: 1.2414...  0.1373 sec/batch
# Epoch: 13/20...  Training Step: 12250...  Training loss: 1.2703...  0.1384 sec/batch
# Epoch: 13/20...  Training Step: 12300...  Training loss: 1.2358...  0.1383 sec/batch
# Epoch: 13/20...  Training Step: 12350...  Training loss: 1.3028...  0.1371 sec/batch
# Epoch: 13/20...  Training Step: 12400...  Training loss: 1.1747...  0.1376 sec/batch
# Epoch: 13/20...  Training Step: 12450...  Training loss: 1.2258...  0.1357 sec/batch
# Epoch: 13/20...  Training Step: 12500...  Training loss: 1.2436...  0.1378 sec/batch
# Epoch: 13/20...  Training Step: 12550...  Training loss: 1.2858...  0.1385 sec/batch
# Epoch: 13/20...  Training Step: 12600...  Training loss: 1.2611...  0.1356 sec/batch
# Epoch: 13/20...  Training Step: 12650...  Training loss: 1.2371...  0.1385 sec/batch
# Epoch: 13/20...  Training Step: 12700...  Training loss: 1.2395...  0.1379 sec/batch
# Epoch: 13/20...  Training Step: 12750...  Training loss: 1.1934...  0.1363 sec/batch
# Epoch: 13/20...  Training Step: 12800...  Training loss: 1.1999...  0.1386 sec/batch
# Epoch: 13/20...  Training Step: 12850...  Training loss: 1.2558...  0.1383 sec/batch
# Epoch: 14/20...  Training Step: 12900...  Training loss: 1.2717...  0.1404 sec/batch
# Epoch: 14/20...  Training Step: 12950...  Training loss: 1.1932...  0.1364 sec/batch
# Epoch: 14/20...  Training Step: 13000...  Training loss: 1.2733...  0.1362 sec/batch
# Epoch: 14/20...  Training Step: 13050...  Training loss: 1.2274...  0.1377 sec/batch
# Epoch: 14/20...  Training Step: 13100...  Training loss: 1.2277...  0.1375 sec/batch
# Epoch: 14/20...  Training Step: 13150...  Training loss: 1.2007...  0.1378 sec/batch
# Epoch: 14/20...  Training Step: 13200...  Training loss: 1.2404...  0.1379 sec/batch
# Epoch: 14/20...  Training Step: 13250...  Training loss: 1.2198...  0.1369 sec/batch
# Epoch: 14/20...  Training Step: 13300...  Training loss: 1.2875...  0.1373 sec/batch
# Epoch: 14/20...  Training Step: 13350...  Training loss: 1.2744...  0.1391 sec/batch
# Epoch: 14/20...  Training Step: 13400...  Training loss: 1.2114...  0.1359 sec/batch
# Epoch: 14/20...  Training Step: 13450...  Training loss: 1.1830...  0.1370 sec/batch
# Epoch: 14/20...  Training Step: 13500...  Training loss: 1.2278...  0.1364 sec/batch
# Epoch: 14/20...  Training Step: 13550...  Training loss: 1.2905...  0.1434 sec/batch
# Epoch: 14/20...  Training Step: 13600...  Training loss: 1.1704...  0.1392 sec/batch
# Epoch: 14/20...  Training Step: 13650...  Training loss: 1.2833...  0.1385 sec/batch
# Epoch: 14/20...  Training Step: 13700...  Training loss: 1.2272...  0.1375 sec/batch
# Epoch: 14/20...  Training Step: 13750...  Training loss: 1.2452...  0.1377 sec/batch
# Epoch: 14/20...  Training Step: 13800...  Training loss: 1.1797...  0.1373 sec/batch
# Epoch: 14/20...  Training Step: 13850...  Training loss: 1.2756...  0.1368 sec/batch
# Epoch: 15/20...  Training Step: 13900...  Training loss: 1.2107...  0.1370 sec/batch
# Epoch: 15/20...  Training Step: 13950...  Training loss: 1.2010...  0.1368 sec/batch
# Epoch: 15/20...  Training Step: 14000...  Training loss: 1.2486...  0.1375 sec/batch
# Epoch: 15/20...  Training Step: 14050...  Training loss: 1.2398...  0.1378 sec/batch
# Epoch: 15/20...  Training Step: 14100...  Training loss: 1.3147...  0.1377 sec/batch
# Epoch: 15/20...  Training Step: 14150...  Training loss: 1.2896...  0.1373 sec/batch
# Epoch: 15/20...  Training Step: 14200...  Training loss: 1.2276...  0.1379 sec/batch
# Epoch: 15/20...  Training Step: 14250...  Training loss: 1.2932...  0.1379 sec/batch
# Epoch: 15/20...  Training Step: 14300...  Training loss: 1.2072...  0.1383 sec/batch
# Epoch: 15/20...  Training Step: 14350...  Training loss: 1.2348...  0.1369 sec/batch
# Epoch: 15/20...  Training Step: 14400...  Training loss: 1.2461...  0.1365 sec/batch
# Epoch: 15/20...  Training Step: 14450...  Training loss: 1.2241...  0.1373 sec/batch
# Epoch: 15/20...  Training Step: 14500...  Training loss: 1.2744...  0.1372 sec/batch
# Epoch: 15/20...  Training Step: 14550...  Training loss: 1.2831...  0.1371 sec/batch
# Epoch: 15/20...  Training Step: 14600...  Training loss: 1.3388...  0.1365 sec/batch
# Epoch: 15/20...  Training Step: 14650...  Training loss: 1.1935...  0.1360 sec/batch
# Epoch: 15/20...  Training Step: 14700...  Training loss: 1.2909...  0.1352 sec/batch
# Epoch: 15/20...  Training Step: 14750...  Training loss: 1.1904...  0.1401 sec/batch
# Epoch: 15/20...  Training Step: 14800...  Training loss: 1.2371...  0.1375 sec/batch
# Epoch: 15/20...  Training Step: 14850...  Training loss: 1.2196...  0.1368 sec/batch
# Epoch: 16/20...  Training Step: 14900...  Training loss: 1.1903...  0.1368 sec/batch
# Epoch: 16/20...  Training Step: 14950...  Training loss: 1.2217...  0.1372 sec/batch
# Epoch: 16/20...  Training Step: 15000...  Training loss: 1.2345...  0.1389 sec/batch
# Epoch: 16/20...  Training Step: 15050...  Training loss: 1.2202...  0.1340 sec/batch
# Epoch: 16/20...  Training Step: 15100...  Training loss: 1.1765...  0.1369 sec/batch
# Epoch: 16/20...  Training Step: 15150...  Training loss: 1.1798...  0.1375 sec/batch
# Epoch: 16/20...  Training Step: 15200...  Training loss: 1.2437...  0.1371 sec/batch
# Epoch: 16/20...  Training Step: 15250...  Training loss: 1.1655...  0.1371 sec/batch
# Epoch: 16/20...  Training Step: 15300...  Training loss: 1.2862...  0.1373 sec/batch
# Epoch: 16/20...  Training Step: 15350...  Training loss: 1.3148...  0.1384 sec/batch
# Epoch: 16/20...  Training Step: 15400...  Training loss: 1.1945...  0.1346 sec/batch
# Epoch: 16/20...  Training Step: 15450...  Training loss: 1.1585...  0.1379 sec/batch
# Epoch: 16/20...  Training Step: 15500...  Training loss: 1.1875...  0.1386 sec/batch
# Epoch: 16/20...  Training Step: 15550...  Training loss: 1.2160...  0.1368 sec/batch
# Epoch: 16/20...  Training Step: 15600...  Training loss: 1.3615...  0.1366 sec/batch
# Epoch: 16/20...  Training Step: 15650...  Training loss: 1.2186...  0.1378 sec/batch
# Epoch: 16/20...  Training Step: 15700...  Training loss: 1.2650...  0.1375 sec/batch
# Epoch: 16/20...  Training Step: 15750...  Training loss: 1.3356...  0.1368 sec/batch
# Epoch: 16/20...  Training Step: 15800...  Training loss: 1.2586...  0.1389 sec/batch
# Epoch: 16/20...  Training Step: 15850...  Training loss: 1.4675...  0.1389 sec/batch
# Epoch: 17/20...  Training Step: 15900...  Training loss: 1.1966...  0.1379 sec/batch
# Epoch: 17/20...  Training Step: 15950...  Training loss: 1.2330...  0.1366 sec/batch
# Epoch: 17/20...  Training Step: 16000...  Training loss: 1.2265...  0.1369 sec/batch
# Epoch: 17/20...  Training Step: 16050...  Training loss: 1.3513...  0.1371 sec/batch
# Epoch: 17/20...  Training Step: 16100...  Training loss: 1.2818...  0.1377 sec/batch
# Epoch: 17/20...  Training Step: 16150...  Training loss: 1.1040...  0.1383 sec/batch
# Epoch: 17/20...  Training Step: 16200...  Training loss: 1.2373...  0.1372 sec/batch
# Epoch: 17/20...  Training Step: 16250...  Training loss: 1.2254...  0.1382 sec/batch
# Epoch: 17/20...  Training Step: 16300...  Training loss: 1.3016...  0.1373 sec/batch
# Epoch: 17/20...  Training Step: 16350...  Training loss: 1.2231...  0.1370 sec/batch
# Epoch: 17/20...  Training Step: 16400...  Training loss: 1.2053...  0.1386 sec/batch
# Epoch: 17/20...  Training Step: 16450...  Training loss: 1.3571...  0.1371 sec/batch
# Epoch: 17/20...  Training Step: 16500...  Training loss: 1.2340...  0.1375 sec/batch
# Epoch: 17/20...  Training Step: 16550...  Training loss: 1.2033...  0.1377 sec/batch
# Epoch: 17/20...  Training Step: 16600...  Training loss: 1.2559...  0.1374 sec/batch
# Epoch: 17/20...  Training Step: 16650...  Training loss: 1.2015...  0.1375 sec/batch
# Epoch: 17/20...  Training Step: 16700...  Training loss: 1.2934...  0.1371 sec/batch
# Epoch: 17/20...  Training Step: 16750...  Training loss: 1.2431...  0.1361 sec/batch
# Epoch: 17/20...  Training Step: 16800...  Training loss: 1.2403...  0.1362 sec/batch
# Epoch: 17/20...  Training Step: 16850...  Training loss: 1.2863...  0.1373 sec/batch
# Epoch: 18/20...  Training Step: 16900...  Training loss: 1.2848...  0.1361 sec/batch
# Epoch: 18/20...  Training Step: 16950...  Training loss: 1.2475...  0.1379 sec/batch
# Epoch: 18/20...  Training Step: 17000...  Training loss: 1.2741...  0.1373 sec/batch
# Epoch: 18/20...  Training Step: 17050...  Training loss: 1.2771...  0.1367 sec/batch
# Epoch: 18/20...  Training Step: 17100...  Training loss: 1.2333...  0.1384 sec/batch
# Epoch: 18/20...  Training Step: 17150...  Training loss: 1.1522...  0.1369 sec/batch
# Epoch: 18/20...  Training Step: 17200...  Training loss: 1.2564...  0.1384 sec/batch
# Epoch: 18/20...  Training Step: 17250...  Training loss: 1.2200...  0.1388 sec/batch
# Epoch: 18/20...  Training Step: 17300...  Training loss: 1.2082...  0.1384 sec/batch
# Epoch: 18/20...  Training Step: 17350...  Training loss: 1.1844...  0.1359 sec/batch
# Epoch: 18/20...  Training Step: 17400...  Training loss: 1.1771...  0.1377 sec/batch
# Epoch: 18/20...  Training Step: 17450...  Training loss: 1.2320...  0.1383 sec/batch
# Epoch: 18/20...  Training Step: 17500...  Training loss: 1.1923...  0.1383 sec/batch
# Epoch: 18/20...  Training Step: 17550...  Training loss: 1.2758...  0.1387 sec/batch
# Epoch: 18/20...  Training Step: 17600...  Training loss: 1.2441...  0.1372 sec/batch
# Epoch: 18/20...  Training Step: 17650...  Training loss: 1.2217...  0.1365 sec/batch
# Epoch: 18/20...  Training Step: 17700...  Training loss: 1.2002...  0.1363 sec/batch
# Epoch: 18/20...  Training Step: 17750...  Training loss: 1.2967...  0.1380 sec/batch
# Epoch: 18/20...  Training Step: 17800...  Training loss: 1.2985...  0.1385 sec/batch
# Epoch: 18/20...  Training Step: 17850...  Training loss: 1.1760...  0.1360 sec/batch
# Epoch: 19/20...  Training Step: 17900...  Training loss: 1.1988...  0.1378 sec/batch
# Epoch: 19/20...  Training Step: 17950...  Training loss: 1.1213...  0.1374 sec/batch
# Epoch: 19/20...  Training Step: 18000...  Training loss: 1.2088...  0.1362 sec/batch
# Epoch: 19/20...  Training Step: 18050...  Training loss: 1.3127...  0.1397 sec/batch
# Epoch: 19/20...  Training Step: 18100...  Training loss: 1.2755...  0.1383 sec/batch
# Epoch: 19/20...  Training Step: 18150...  Training loss: 1.1952...  0.1383 sec/batch
# Epoch: 19/20...  Training Step: 18200...  Training loss: 1.2625...  0.1392 sec/batch
# Epoch: 19/20...  Training Step: 18250...  Training loss: 1.1784...  0.1376 sec/batch
# Epoch: 19/20...  Training Step: 18300...  Training loss: 1.2489...  0.1374 sec/batch
# Epoch: 19/20...  Training Step: 18350...  Training loss: 1.2114...  0.1364 sec/batch
# Epoch: 19/20...  Training Step: 18400...  Training loss: 1.2019...  0.1371 sec/batch
# Epoch: 19/20...  Training Step: 18450...  Training loss: 1.1753...  0.1375 sec/batch
# Epoch: 19/20...  Training Step: 18500...  Training loss: 1.2102...  0.1371 sec/batch
# Epoch: 19/20...  Training Step: 18550...  Training loss: 1.2047...  0.1384 sec/batch
# Epoch: 19/20...  Training Step: 18600...  Training loss: 1.2897...  0.1368 sec/batch
# Epoch: 19/20...  Training Step: 18650...  Training loss: 1.1793...  0.1379 sec/batch
# Epoch: 19/20...  Training Step: 18700...  Training loss: 1.2865...  0.1365 sec/batch
# Epoch: 19/20...  Training Step: 18750...  Training loss: 1.2024...  0.1378 sec/batch
# Epoch: 19/20...  Training Step: 18800...  Training loss: 1.2377...  0.1372 sec/batch
# Epoch: 20/20...  Training Step: 18850...  Training loss: 1.1896...  0.1373 sec/batch
# Epoch: 20/20...  Training Step: 18900...  Training loss: 1.2708...  0.1406 sec/batch
# Epoch: 20/20...  Training Step: 18950...  Training loss: 1.2357...  0.1374 sec/batch
# Epoch: 20/20...  Training Step: 19000...  Training loss: 1.2441...  0.1365 sec/batch
# Epoch: 20/20...  Training Step: 19050...  Training loss: 1.2385...  0.1356 sec/batch
# Epoch: 20/20...  Training Step: 19100...  Training loss: 1.2073...  0.1370 sec/batch
# Epoch: 20/20...  Training Step: 19150...  Training loss: 1.1539...  0.1378 sec/batch
# Epoch: 20/20...  Training Step: 19200...  Training loss: 1.2181...  0.1376 sec/batch
# Epoch: 20/20...  Training Step: 19250...  Training loss: 1.2154...  0.1369 sec/batch
# Epoch: 20/20...  Training Step: 19300...  Training loss: 1.2140...  0.1372 sec/batch
# Epoch: 20/20...  Training Step: 19350...  Training loss: 1.1933...  0.1363 sec/batch
# Epoch: 20/20...  Training Step: 19400...  Training loss: 1.1492...  0.1342 sec/batch
# Epoch: 20/20...  Training Step: 19450...  Training loss: 1.1784...  0.1389 sec/batch
# Epoch: 20/20...  Training Step: 19500...  Training loss: 1.2578...  0.1376 sec/batch
# Epoch: 20/20...  Training Step: 19550...  Training loss: 1.2270...  0.1360 sec/batch
# Epoch: 20/20...  Training Step: 19600...  Training loss: 1.1848...  0.1383 sec/batch
# Epoch: 20/20...  Training Step: 19650...  Training loss: 1.2757...  0.1389 sec/batch
# Epoch: 20/20...  Training Step: 19700...  Training loss: 1.3029...  0.1380 sec/batch
# Epoch: 20/20...  Training Step: 19750...  Training loss: 1.2007...  0.1351 sec/batch
# Epoch: 20/20...  Training Step: 19800...  Training loss: 1.2038...  0.1381 sec/batch

# %% [markdown]
# #### Saved checkpoints
#
# Read up on saving and loading checkpoints here: https://www.tensorflow.org/programmers_guide/variables

# %%
tf.train.get_checkpoint_state('checkpoints')
# Out:
# model_checkpoint_path: "checkpoints/i19840_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i200_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i400_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i600_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i800_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i1000_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i1200_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i1400_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i1600_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i1800_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i2000_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i2200_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i2400_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i2600_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i2800_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i3000_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i3200_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i3400_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i3600_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i3800_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i4000_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i4200_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i4400_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i4600_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i4800_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i5000_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i5200_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i5400_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i5600_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i5800_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i6000_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i6200_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i6400_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i6600_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i6800_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i7000_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i7200_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i7400_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i7600_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i7800_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i8000_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i8200_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i8400_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i8600_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i8800_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i9000_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i9200_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i9400_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i9600_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i9800_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i10000_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i10200_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i10400_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i10600_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i10800_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i11000_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i11200_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i11400_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i11600_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i11800_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i12000_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i12200_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i12400_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i12600_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i12800_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i13000_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i13200_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i13400_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i13600_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i13800_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i14000_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i14200_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i14400_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i14600_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i14800_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i15000_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i15200_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i15400_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i15600_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i15800_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i16000_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i16200_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i16400_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i16600_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i16800_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i17000_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i17200_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i17400_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i17600_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i17800_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i18000_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i18200_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i18400_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i18600_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i18800_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i19000_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i19200_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i19400_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i19600_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i19800_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i19840_l512.ckpt"

# %% [markdown]
# ## Sampling
#
# Now that the network is trained, we'll can use it to generate new text. The idea is that we pass in a character, then the network will predict the next character. We can use the new one, to predict the next one. And we keep doing this to generate all new text. I also included some functionality to prime the network with some text by passing in a string and building up a state from that.
#
# The network gives us predictions for each character. To reduce noise and make things a little less random, I'm going to only choose a new character from the top N most likely characters.

# %%
def pick_top_n(preds, vocab_size, top_n=5):
    p = np.squeeze(preds)
    p[np.argsort(p)[:-top_n]] = 0
    p = p / np.sum(p)
    c = np.random.choice(vocab_size, 1, p=p)[0]
    return c

# %%
def sample(checkpoint, n_samples, lstm_size, vocab_size, prime="The "):
    samples = [c for c in prime]
    model = CharRNN(len(vocab), lstm_size=lstm_size, sampling=True)
    saver = tf.train.Saver()
    with tf.Session() as sess:
        saver.restore(sess, checkpoint)
        new_state = sess.run(model.initial_state)
        for c in prime:
            x = np.zeros((1, 1))
            x[0,0] = vocab_to_int[c]
            feed = {model.inputs: x,
                    model.keep_prob: 1.,
                    model.initial_state: new_state}
            preds, new_state = sess.run([model.prediction, model.final_state], 
                                         feed_dict=feed)

        c = pick_top_n(preds, len(vocab))
        samples.append(int_to_vocab[c])

        for i in range(n_samples):
            x[0,0] = c
            feed = {model.inputs: x,
                    model.keep_prob: 1.,
                    model.initial_state: new_state}
            preds, new_state = sess.run([model.prediction, model.final_state], 
                                         feed_dict=feed)

            c = pick_top_n(preds, len(vocab))
            samples.append(int_to_vocab[c])
        
    return ''.join(samples)

# %% [markdown]
# Here, pass in the path to a checkpoint and sample from the network.

# %%
tf.train.latest_checkpoint('checkpoints')
# Out:
# 'checkpoints/i19840_l512.ckpt'

# %%
checkpoint = tf.train.latest_checkpoint('checkpoints')
samp = sample(checkpoint, 2000, lstm_size, len(vocab), prime="Far")
print(samp)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/i19840_l512.ckpt
# Farasta though it's not sitting here, but they've a cattle women with all the same to see my face to be all side as that he was a possibility, that I want to be standing to her that supper it
# is no moment at a boy of the partners of
# sometimes when she was staring to home, and they
# see her at the storm of a minute and set in tenderness, but he has seemed as they
# has been beginning to be as though all at once sent of my woman. This was still willed, and would have never had a long while to beg you to do anything. I am standing
# a breaks of such a song way of it, and they were settled to tell you into words, the daughter to the chiev and
# the window wished. But he cannot help himself telling me, what's he said of it. I was the cranked
# stand-comperine to this woman and with her, and she's not in the country. But the common."
#
# "Yes,
# that he has
# taken it on a society on me indoniced
# his faith. I can't help
# happiness out of the words
# in which it was as to be suffered and be troubled, where to blow her all wonderful
# fearing house all that, and
# with her and the plough ore, though I can't shan't come with her to be moved away with that," said the princess. "It can't be serenely in the
# person, and she is, a show of his soul in my mistress would not be
# disputes of this
# women, that he held a single and
# their
# soul,
# striving his stocking to an argument..."
#
# "Oh, I'm the minute. That's all to be done? I shall not see my mother to take
# the wide of the second at anyone, there's a strange, in my beauty, all this, and she does not spend his wife," answered Stepan Arkadyevitch, and she standing aliked her from a crates of his course in horror that he
# had no one of his fresh huge
# hotel, but he sen at all, too had not said
# his hand.
#
# "If you may see me, it's the carriage, and this is to make out all short. I wish if
# it haven't still this, and I'd struck my wife?" asked
# Sergey Ivanovitch and send a still, "how is he in him? I'm not all serene and attention without asking me, then
# I'm growing mis

# %%
checkpoint = 'checkpoints/i10000_l512.ckpt'
samp = sample(checkpoint, 1000, lstm_size, len(vocab), prime="Far")
print(samp)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/i10000_l512.ckpt
# Far to be to see him that they were no meanings, and would not be, but that she saw it on himself, and there were not bound the
# mother of which he had been sentident with
# his fashion in the carpenters, the
# platform. Anna had a soul out in a sound and
# his
# stronger all on his hands
# on
# the door and him too to be anything still an importance
# in his
# soul of her heart.
#
# "It's not ask her. If you can't ball," he asked she caught the minning
# with woundings. The set hands had told
# him it
# on the peasant of the death with something showing at the match together of serious thing which turned them.
#
# Annushka was talking of his soul and said the moment
# of her considerable since shooting as though he was a life, with the consideration of
# the cornice. They asked that it was
# angry
# and himself. He was a conversation as standing her
# face to be so sat on the single as though
# should be,
# and was new, and so, what they were saying, and there was all start of than all his confidence, and to despair too would say.

# %%
checkpoint = 'checkpoints/i600_l512.ckpt'
samp = sample(checkpoint, 1000, lstm_size, len(vocab), prime="Far")
print(samp)

# %%
checkpoint = 'checkpoints/i1200_l512.ckpt'
samp = sample(checkpoint, 1000, lstm_size, len(vocab), prime="Far")
print(samp)
