# %% [markdown]
# # Anna KaRNNa
#
# In this notebook, we'll build a character-wise RNN trained on Anna Karenina, one of my all-time favorite books. It'll be able to generate new text based on the text from the book.
#
# This network is based off of Andrej Karpathy's [post on RNNs](http://karpathy.github.io/2015/05/21/rnn-effectiveness/) and [implementation in Torch](https://github.com/karpathy/char-rnn). Also, some information [here at r2rt](http://r2rt.com/recurrent-neural-networks-in-tensorflow-ii.html) and from [Sherjil Ozair](https://github.com/sherjilozair/char-rnn-tensorflow) on GitHub. Below is the general architecture of the character-wise RNN.
#
# <img src="assets/charseq.jpeg" width="500">

# %%
import time
from collections import namedtuple

import numpy as np
import tensorflow as tf

# %% [markdown]
# First we'll load the text file and convert it into integers for our network to use. Here I'm creating a couple dictionaries to convert the characters to and from integers. Encoding the characters as integers makes it easier to use as input in the network.

# %%
with open('anna.txt', 'r') as f:
    text=f.read()
vocab = sorted(set(text))
vocab_to_int = {c: i for i, c in enumerate(vocab)}
int_to_vocab = dict(enumerate(vocab))
encoded = np.array([vocab_to_int[c] for c in text], dtype=np.int32)

# %% [markdown]
# Let's check out the first 100 characters, make sure everything is peachy. According to the [American Book Review](http://americanbookreview.org/100bestlines.asp), this is the 6th best first line of a book ever.

# %%
text[:100]
# Out:
# 'Chapter 1\n\n\nHappy families are all alike; every unhappy family is unhappy in its own\nway.\n\nEverythin'

# %% [markdown]
# And we can see the characters encoded as integers.

# %%
encoded[:100]
# Out:
# array([31, 64, 57, 72, 76, 61, 74,  1, 16,  0,  0,  0, 36, 57, 72, 72, 81,
#         1, 62, 57, 69, 65, 68, 65, 61, 75,  1, 57, 74, 61,  1, 57, 68, 68,
#         1, 57, 68, 65, 67, 61, 26,  1, 61, 78, 61, 74, 81,  1, 77, 70, 64,
#        57, 72, 72, 81,  1, 62, 57, 69, 65, 68, 81,  1, 65, 75,  1, 77, 70,
#        64, 57, 72, 72, 81,  1, 65, 70,  1, 65, 76, 75,  1, 71, 79, 70,  0,
#        79, 57, 81, 13,  0,  0, 33, 78, 61, 74, 81, 76, 64, 65, 70],
#       dtype=int32)

# %% [markdown]
# Since the network is working with individual characters, it's similar to a classification problem in which we are trying to predict the next character from the previous text.  Here's how many 'classes' our network has to pick from.

# %%
len(vocab)
# Out:
# 83

# %% [markdown]
# ## Making training mini-batches
#
# Here is where we'll make our mini-batches for training. Remember that we want our batches to be multiple sequences of some desired number of sequence steps. Considering a simple example, our batches would look like this:
#
# <img src="assets/sequence_batching@1x.png" width=500px>
#
#
# <br>
#
# We start with our text encoded as integers in one long array in `encoded`. Let's create a function that will give us an iterator for our batches. I like using [generator functions](https://jeffknupp.com/blog/2013/04/07/improve-your-python-yield-and-generators-explained/) to do this. Then we can pass `encoded` into this function and get our batch generator.
#
# The first thing we need to do is discard some of the text so we only have completely full batches. Each batch contains $N \times M$ characters, where $N$ is the batch size (the number of sequences) and $M$ is the number of steps. Then, to get the total number of batches, $K$, we can make from the array `arr`, you divide the length of `arr` by the number of characters per batch. Once you know the number of batches, you can get the total number of characters to keep from `arr`, $N * M * K$.
#
# After that, we need to split `arr` into $N$ sequences. You can do this using `arr.reshape(size)` where `size` is a tuple containing the dimensions sizes of the reshaped array. We know we want $N$ sequences (`batch_size` below), let's make that the size of the first dimension. For the second dimension, you can use `-1` as a placeholder in the size, it'll fill up the array with the appropriate data for you. After this, you should have an array that is $N \times (M * K)$.
#
# Now that we have this array, we can iterate through it to get our batches. The idea is each batch is a $N \times M$ window on the $N \times (M * K)$ array. For each subsequent batch, the window moves over by `n_steps`. We also want to create both the input and target arrays. Remember that the targets are the inputs shifted over one character.
#
# The way I like to do this window is use `range` to take steps of size `n_steps` from $0$ to `arr.shape[1]`, the total number of steps in each sequence. That way, the integers you get from `range` always point to the start of a batch, and each window is `n_steps` wide.
#
# > **Exercise:** Write the code for creating batches in the function below. The exercises in this notebook _will not be easy_. I've provided a notebook with solutions alongside this notebook. If you get stuck, checkout the solutions. The most important thing is that you don't copy and paste the code into here, **type out the solution code yourself.**

# %%
def get_batches(arr, batch_size, n_steps):
    '''Create a generator that returns batches of size
       batch_size x n_steps from arr.
       
       Arguments
       ---------
       arr: Array you want to make batches from
       batch_size: Batch size, the number of sequences per batch
       n_steps: Number of sequence steps per batch
    '''
    # Get the number of characters per batch and number of batches we can make
    chars_per_batch = batch_size * n_steps
    n_batches = len(arr) // chars_per_batch
    
    # Keep only enough characters to make full batches
    arr = arr[:n_batches * chars_per_batch]
    
    # Reshape into batch_size rows
    arr = arr.reshape((batch_size, -1))
    
    for n in range(0, arr.shape[1], n_steps):
        # The features
        x = arr[:, n:n+n_steps]
        # The targets, shifted by one
        y_temp = arr[:, n + 1:n + n_steps + 1]
        
        # For the very last batch, y will be one character short at the end of 
        # the sequences which breaks things. To get around this, I'll make an 
        # array of the appropriate size first, of all zeros, then add the targets.
        # This will introduce a small artifact in the last batch, but it won't matter.
        y = np.zeros(x.shape, dtype=x.dtype)
        y[:, :y_temp.shape[1]] = y_temp
        
        yield x, y

# %% [markdown]
# Now I'll make my data sets and we can check out what's going on here. Here I'm going to use a batch size of 10 and 50 sequence steps.

# %%
batches = get_batches(encoded, 10, 50)
x, y = next(batches)

# %%
print('x\n', x[:10, :10])
print('\ny\n', y[:10, :10])
# Out:
# x
#  [[31 64 57 72 76 61 74  1 16  0]
#  [ 1 57 69  1 70 71 76  1 63 71]
#  [78 65 70 13  0  0  3 53 61 75]
#  [70  1 60 77 74 65 70 63  1 64]
#  [ 1 65 76  1 65 75 11  1 75 65]
#  [ 1 37 76  1 79 57 75  0 71 70]
#  [64 61 70  1 59 71 69 61  1 62]
#  [26  1 58 77 76  1 70 71 79  1]
#  [76  1 65 75 70  7 76 13  1 48]
#  [ 1 75 57 65 60  1 76 71  1 64]]
#
# y
#  [[64 57 72 76 61 74  1 16  0  0]
#  [57 69  1 70 71 76  1 63 71 65]
#  [65 70 13  0  0  3 53 61 75 11]
#  [ 1 60 77 74 65 70 63  1 64 65]
#  [65 76  1 65 75 11  1 75 65 74]
#  [37 76  1 79 57 75  0 71 70 68]
#  [61 70  1 59 71 69 61  1 62 71]
#  [ 1 58 77 76  1 70 71 79  1 75]
#  [ 1 65 75 70  7 76 13  1 48 64]
#  [75 57 65 60  1 76 71  1 64 61]]

# %% [markdown]
# If you implemented `get_batches` correctly, the above output should look something like
# ```
# x
#  [[55 63 69 22  6 76 45  5 16 35]
#  [ 5 69  1  5 12 52  6  5 56 52]
#  [48 29 12 61 35 35  8 64 76 78]
#  [12  5 24 39 45 29 12 56  5 63]
#  [ 5 29  6  5 29 78 28  5 78 29]
#  [ 5 13  6  5 36 69 78 35 52 12]
#  [63 76 12  5 18 52  1 76  5 58]
#  [34  5 73 39  6  5 12 52 36  5]
#  [ 6  5 29 78 12 79  6 61  5 59]
#  [ 5 78 69 29 24  5  6 52  5 63]]
#
# y
#  [[63 69 22  6 76 45  5 16 35 35]
#  [69  1  5 12 52  6  5 56 52 29]
#  [29 12 61 35 35  8 64 76 78 28]
#  [ 5 24 39 45 29 12 56  5 63 29]
#  [29  6  5 29 78 28  5 78 29 45]
#  [13  6  5 36 69 78 35 52 12 43]
#  [76 12  5 18 52  1 76  5 58 52]
#  [ 5 73 39  6  5 12 52 36  5 78]
#  [ 5 29 78 12 79  6 61  5 59 63]
#  [78 69 29 24  5  6 52  5 63 76]]
#  ```
#  although the exact numbers will be different. Check to make sure the data is shifted over one step for `y`.

# %% [markdown]
# ## Building the model
#
# Below is where you'll build the network. We'll break it up into parts so it's easier to reason about each bit. Then we can connect them up into the whole network.
#
# <img src="assets/charRNN.png" width=500px>
#
#
# ### Inputs
#
# First off we'll create our input placeholders. As usual we need placeholders for the training data and the targets. We'll also create a placeholder for dropout layers called `keep_prob`. This will be a scalar, that is a 0-D tensor. To make a scalar, you create a placeholder without giving it a size.
#
# > **Exercise:** Create the input placeholders in the function below.

# %%
def build_inputs(batch_size, num_steps):
    ''' Define placeholders for inputs, targets, and dropout 
    
        Arguments
        ---------
        batch_size: Batch size, number of sequences per batch
        num_steps: Number of sequence steps in a batch
        
    '''
    # Declare placeholders we'll feed into the graph
    inputs = tf.placeholder(tf.int32, [batch_size, num_steps], 
                            name='inputs')
    targets = tf.placeholder(tf.int32, [batch_size, num_steps], 
                            name='targets')
    
    # Keep probability placeholder for drop out layers
    keep_prob = tf.placeholder(tf.float32, name='keep_prob')
    
    return inputs, targets, keep_prob

# %% [markdown]
# ### LSTM Cell
#
# Here we will create the LSTM cell we'll use in the hidden layer. We'll use this cell as a building block for the RNN. So we aren't actually defining the RNN here, just the type of cell we'll use in the hidden layer.
#
# We first create a basic LSTM cell with
#
# ```python
# lstm = tf.contrib.rnn.BasicLSTMCell(num_units)
# ```
#
# where `num_units` is the number of units in the hidden layers in the cell. Then we can add dropout by wrapping it with
#
# ```python
# tf.contrib.rnn.DropoutWrapper(lstm, output_keep_prob=keep_prob)
# ```
# You pass in a cell and it will automatically add dropout to the inputs or outputs. Finally, we can stack up the LSTM cells into layers with [`tf.contrib.rnn.MultiRNNCell`](https://www.tensorflow.org/versions/r1.0/api_docs/python/tf/contrib/rnn/MultiRNNCell). With this, you pass in a list of cells and it will send the output of one cell into the next cell. Previously with TensorFlow 1.0, you could do this
#
# ```python
# tf.contrib.rnn.MultiRNNCell([cell]*num_layers)
# ```
#
# This might look a little weird if you know Python well because this will create a list of the same `cell` object. However, TensorFlow 1.0 will create different weight matrices for all `cell` objects. But, starting with TensorFlow 1.1 you actually need to create new cell objects in the list. To get it to work in TensorFlow 1.1, it should look like
#
# ```python
# def build_cell(num_units, keep_prob):
#     lstm = tf.contrib.rnn.BasicLSTMCell(num_units)
#     drop = tf.contrib.rnn.DropoutWrapper(lstm, output_keep_prob=keep_prob)
#
#     return drop
#
# tf.contrib.rnn.MultiRNNCell([build_cell(num_units, keep_prob) for _ in range(num_layers)])
# ```
#
# Even though this is actually multiple LSTM cells stacked on each other, you can treat the multiple layers as one cell.
#
# We also need to create an initial cell state of all zeros. This can be done like so
#
# ```python
# initial_state = cell.zero_state(batch_size, tf.float32)
# ```
#
# Below, we implement the `build_lstm` function to create these LSTM cells and the initial state.

# %%
def build_lstm(lstm_size, num_layers, batch_size, keep_prob):
    ''' Build LSTM cell.
    
        Arguments
        ---------
        keep_prob: Scalar tensor (tf.placeholder) for the dropout keep probability
        lstm_size: Size of the hidden layers in the LSTM cells
        num_layers: Number of LSTM layers
        batch_size: Batch size

    '''
    ### Build the LSTM Cell
    def build_cell(lstm_size, keep_prob):
        # Use a basic LSTM cell
        lstm = tf.contrib.rnn.BasicLSTMCell(lstm_size)
        
        # Add dropout to the cell outputs
        drop = tf.contrib.rnn.DropoutWrapper(lstm, output_keep_prob=keep_prob)
        return drop
    
    # Stack up multiple LSTM layers, for deep learning
    cell = tf.contrib.rnn.MultiRNNCell([build_cell(lstm_size, keep_prob) for _ in range(num_layers)])
    initial_state = cell.zero_state(batch_size, tf.float32)
    
    return cell, initial_state

# %% [markdown]
# ### RNN Output
#
# Here we'll create the output layer. We need to connect the output of the RNN cells to a full connected layer with a softmax output. The softmax output gives us a probability distribution we can use to predict the next character, so we want this layer to have size $C$, the number of classes/characters we have in our text.
#
# If our input has batch size $N$, number of steps $M$, and the hidden layer has $L$ hidden units, then the output is a 3D tensor with size $N \times M \times L$. The output of each LSTM cell has size $L$, we have $M$ of them, one for each sequence step, and we have $N$ sequences. So the total size is $N \times M \times L$.
#
# We are using the same fully connected layer, the same weights, for each of the outputs. Then, to make things easier, we should reshape the outputs into a 2D tensor with shape $(M * N) \times L$. That is, one row for each sequence and step, where the values of each row are the output from the LSTM cells. We get the LSTM output as a list, `lstm_output`. First we need to concatenate this whole list into one array with [`tf.concat`](https://www.tensorflow.org/api_docs/python/tf/concat). Then, reshape it (with `tf.reshape`) to size $(M * N) \times L$.
#
# One we have the outputs reshaped, we can do the matrix multiplication with the weights. We need to wrap the weight and bias variables in a variable scope with `tf.variable_scope(scope_name)` because there are weights being created in the LSTM cells. TensorFlow will throw an error if the weights created here have the same names as the weights created in the LSTM cells, which they will be default. To avoid this, we wrap the variables in a variable scope so we can give them unique names.
#
# > **Exercise:** Implement the output layer in the function below.

# %%
def build_output(lstm_output, in_size, out_size):
    ''' Build a softmax layer, return the softmax output and logits.
    
        Arguments
        ---------
        
        lstm_output: List of output tensors from the LSTM layer
        in_size: Size of the input tensor, for example, size of the LSTM cells
        out_size: Size of this softmax layer
    
    '''

    # Reshape output so it's a bunch of rows, one row for each step for 
    # each sequence. Concatenate lstm_output over axis 1 (the columns)
    seq_output = tf.concat(lstm_output, axis=1)
    # Reshape seq_output to a 2D tensor with lstm_size columns
    x = tf.reshape(seq_output, [-1, lstm_size])
    
    # Connect the RNN outputs to a softmax layer
    with tf.variable_scope('softmax'):
        # Create the weight and bias variables here
        softmax_w = tf.Variable(tf.truncated_normal((in_size, out_size), 
                                                    stddev=0.1))
        softmax_b = tf.Variable(tf.zeros(out_size))
    
    # Since output is a bunch of rows of RNN cell outputs, logits will 
    # be a bunch of rows of logit outputs, one for each step and 
    # sequence
    logits = tf.matmul(x, softmax_w) + softmax_b
    
    # Use softmax to get the probabilities for predicted characters
    out = tf.nn.softmax(logits, name='predictions')
    
    return out, logits

# %% [markdown]
# ### Training loss
#
# Next up is the training loss. We get the logits and targets and calculate the softmax cross-entropy loss. First we need to one-hot encode the targets, we're getting them as encoded characters. Then, reshape the one-hot targets so it's a 2D tensor with size $(M*N) \times C$ where $C$ is the number of classes/characters we have. Remember that we reshaped the LSTM outputs and ran them through a fully connected layer with $C$ units. So our logits will also have size $(M*N) \times C$.
#
# Then we run the logits and targets through `tf.nn.softmax_cross_entropy_with_logits` and find the mean to get the loss.
#
# >**Exercise:** Implement the loss calculation in the function below.

# %%
def build_loss(logits, targets, lstm_size, num_classes):
    ''' Calculate the loss from the logits and the targets.
    
        Arguments
        ---------
        logits: Logits from final fully connected layer
        targets: Targets for supervised learning
        lstm_size: Number of LSTM hidden units
        num_classes: Number of classes in targets
        
    '''
    
    # One-hot encode targets and reshape to match logits, one row per 
    # sequence per step
    y_one_hot = tf.one_hot(targets, num_classes)
    y_reshaped = tf.reshape(y_one_hot, logits.get_shape())
    
    # Softmax cross entropy loss
    loss = tf.nn.softmax_cross_entropy_with_logits_v2(logits=logits, 
                                                      labels=y_reshaped)
    loss = tf.reduce_mean(loss)
    
    return loss

# %% [markdown]
# ### Optimizer
#
# Here we build the optimizer. Normal RNNs have have issues gradients exploding and disappearing. LSTMs fix the disappearance problem, but the gradients can still grow without bound. To fix this, we can clip the gradients above some threshold. That is, if a gradient is larger than that threshold, we set it to the threshold. This will ensure the gradients never grow overly large. Then we use an AdamOptimizer for the learning step.

# %%
def build_optimizer(loss, learning_rate, grad_clip):
    ''' Build optmizer for training, using gradient clipping.
    
        Arguments:
        loss: Network loss
        learning_rate: Learning rate for optimizer
    
    '''
    
    # Optimizer for training, using gradient clipping to control 
    # exploding gradients
    tvars = tf.trainable_variables()
    grads, _ = tf.clip_by_global_norm(tf.gradients(loss, tvars), 
                                      grad_clip)
    train_op = tf.train.AdamOptimizer(learning_rate)
    optimizer = train_op.apply_gradients(zip(grads, tvars))
    
    return optimizer

# %% [markdown]
# ### Build the network
#
# Now we can put all the pieces together and build a class for the network. To actually run data through the LSTM cells, we will use [`tf.nn.dynamic_rnn`](https://www.tensorflow.org/versions/r1.0/api_docs/python/tf/nn/dynamic_rnn). This function will pass the hidden and cell states across LSTM cells appropriately for us. It returns the outputs for each LSTM cell at each step for each sequence in the mini-batch. It also gives us the final LSTM state. We want to save this state as `final_state` so we can pass it to the first LSTM cell in the the next mini-batch run. For `tf.nn.dynamic_rnn`, we pass in the cell and initial state we get from `build_lstm`, as well as our input sequences. Also, we need to one-hot encode the inputs before going into the RNN.
#
# > **Exercise:** Use the functions you've implemented previously and `tf.nn.dynamic_rnn` to build the network.

# %%
class CharRNN:
    
    def __init__(self, num_classes, batch_size=64, num_steps=50, 
                 lstm_size=128, num_layers=2, learning_rate=0.001, 
                 grad_clip=5, sampling=False):
    
        # When we're using this network for sampling later, we'll be 
        # passing in one character at a time, so providing an option 
        # for that
        if sampling == True:
            batch_size, num_steps = 1, 1
        else:
            batch_size, num_steps = batch_size, num_steps

        tf.reset_default_graph()
        
        # Build the input placeholder tensors
        self.inputs, self.targets, self.keep_prob = build_inputs(batch_size, num_steps)

        # Build the LSTM cell
        cell, self.initial_state = build_lstm(lstm_size, num_layers, batch_size, self.keep_prob)

        ### Run the data through the RNN layers
        # First, one-hot encode the input tokens
        x_one_hot = tf.one_hot(self.inputs, num_classes)
        
        # Run each sequence step through the RNN with tf.nn.dynamic_rnn
        outputs, state = tf.nn.dynamic_rnn(cell, x_one_hot, initial_state=self.initial_state)
        self.final_state = state
        
        # Get softmax predictions and logits
        self.prediction, self.logits = build_output(outputs, lstm_size, num_classes)
        
        # Loss and optimizer (with gradient clipping)
        self.loss = build_loss(self.logits, self.targets, lstm_size, num_classes)
        self.optimizer = build_optimizer(self.loss, learning_rate, grad_clip)

# %% [markdown]
# ## Hyperparameters
#
# Here are the hyperparameters for the network.
#
# * `batch_size` - Number of sequences running through the network in one pass.
# * `num_steps` - Number of characters in the sequence the network is trained on. Larger is better typically, the network will learn more long range dependencies. But it takes longer to train. 100 is typically a good number here.
# * `lstm_size` - The number of units in the hidden layers.
# * `num_layers` - Number of hidden LSTM layers to use
# * `learning_rate` - Learning rate for training
# * `keep_prob` - The dropout keep probability when training. If you're network is overfitting, try decreasing this.
#
# Here's some good advice from Andrej Karpathy on training the network. I'm going to copy it in here for your benefit, but also link to [where it originally came from](https://github.com/karpathy/char-rnn#tips-and-tricks).
#
# > ## Tips and Tricks
#
# >### Monitoring Validation Loss vs. Training Loss
# >If you're somewhat new to Machine Learning or Neural Networks it can take a bit of expertise to get good models. The most important quantity to keep track of is the difference between your training loss (printed during training) and the validation loss (printed once in a while when the RNN is run on the validation data (by default every 1000 iterations)). In particular:
#
# > - If your training loss is much lower than validation loss then this means the network might be **overfitting**. Solutions to this are to decrease your network size, or to increase dropout. For example you could try dropout of 0.5 and so on.
# > - If your training/validation loss are about equal then your model is **underfitting**. Increase the size of your model (either number of layers or the raw number of neurons per layer)
#
# > ### Approximate number of parameters
#
# > The two most important parameters that control the model are `lstm_size` and `num_layers`. I would advise that you always use `num_layers` of either 2/3. The `lstm_size` can be adjusted based on how much data you have. The two important quantities to keep track of here are:
#
# > - The number of parameters in your model. This is printed when you start training.
# > - The size of your dataset. 1MB file is approximately 1 million characters.
#
# >These two should be about the same order of magnitude. It's a little tricky to tell. Here are some examples:
#
# > - I have a 100MB dataset and I'm using the default parameter settings (which currently print 150K parameters). My data size is significantly larger (100 mil >> 0.15 mil), so I expect to heavily underfit. I am thinking I can comfortably afford to make `lstm_size` larger.
# > - I have a 10MB dataset and running a 10 million parameter model. I'm slightly nervous and I'm carefully monitoring my validation loss. If it's larger than my training loss then I may want to try to increase dropout a bit and see if that helps the validation loss.
#
# > ### Best models strategy
#
# >The winning strategy to obtaining very good models (if you have the compute time) is to always err on making the network larger (as large as you're willing to wait for it to compute) and then try different dropout values (between 0,1). Whatever model has the best validation performance (the loss, written in the checkpoint filename, low is good) is the one you should use in the end.
#
# >It is very common in deep learning to run many different models with many different hyperparameter settings, and in the end take whatever checkpoint gave the best validation performance.
#
# >By the way, the size of your training and validation splits are also parameters. Make sure you have a decent amount of data in your validation set or otherwise the validation performance will be noisy and not very informative.

# %%
batch_size = 10         # Sequences per batch
num_steps = 50          # Number of sequence steps per batch
lstm_size = 256         # Size of hidden layers in LSTMs
num_layers = 2          # Number of LSTM layers
learning_rate = 0.01    # Learning rate
keep_prob = 0.5         # Dropout keep probability

# %% [markdown]
# ## Time for training
#
# This is typical training code, passing inputs and targets into the network, then running the optimizer. Here we also get back the final LSTM state for the mini-batch. Then, we pass that state back into the network so the next batch can continue the state from the previous batch. And every so often (set by `save_every_n`) I save a checkpoint.
#
# Here I'm saving checkpoints with the format
#
# `i{iteration number}_l{# hidden layer units}.ckpt`
#
# > **Exercise:** Set the hyperparameters above to train the network. Watch the training loss, it should be consistently dropping. Also, I highly advise running this on a GPU.

# %%
epochs = 20
# Print losses every N interations
print_every_n = 50

# Save every N iterations
save_every_n = 200

model = CharRNN(len(vocab), batch_size=batch_size, num_steps=num_steps,
                lstm_size=lstm_size, num_layers=num_layers, 
                learning_rate=learning_rate)

saver = tf.train.Saver(max_to_keep=100)
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    
    # Use the line below to load a checkpoint and resume training
    #saver.restore(sess, 'checkpoints/______.ckpt')
    counter = 0
    for e in range(epochs):
        # Train network
        new_state = sess.run(model.initial_state)
        loss = 0
        for x, y in get_batches(encoded, batch_size, num_steps):
            counter += 1
            start = time.time()
            feed = {model.inputs: x,
                    model.targets: y,
                    model.keep_prob: keep_prob,
                    model.initial_state: new_state}
            batch_loss, new_state, _ = sess.run([model.loss, 
                                                 model.final_state, 
                                                 model.optimizer], 
                                                 feed_dict=feed)
            if (counter % print_every_n == 0):
                end = time.time()
                print('Epoch: {}/{}... '.format(e+1, epochs),
                      'Training Step: {}... '.format(counter),
                      'Training loss: {:.4f}... '.format(batch_loss),
                      '{:.4f} sec/batch'.format((end-start)))
        
            if (counter % save_every_n == 0):
                saver.save(sess, "checkpoints/i{}_l{}.ckpt".format(counter, lstm_size))
    
    saver.save(sess, "checkpoints/i{}_l{}.ckpt".format(counter, lstm_size))
# Out:
# Epoch: 1/20...  Training Step: 50...  Training loss: 3.1145...  0.0415 sec/batch
# Epoch: 1/20...  Training Step: 100...  Training loss: 2.6745...  0.0394 sec/batch
# Epoch: 1/20...  Training Step: 150...  Training loss: 2.3797...  0.0389 sec/batch
# Epoch: 1/20...  Training Step: 200...  Training loss: 2.3874...  0.0391 sec/batch
# Epoch: 1/20...  Training Step: 250...  Training loss: 2.2968...  0.0386 sec/batch
# Epoch: 1/20...  Training Step: 300...  Training loss: 2.1467...  0.0387 sec/batch
# Epoch: 1/20...  Training Step: 350...  Training loss: 2.0928...  0.0385 sec/batch
# Epoch: 1/20...  Training Step: 400...  Training loss: 2.1105...  0.0391 sec/batch
# Epoch: 1/20...  Training Step: 450...  Training loss: 2.1076...  0.0386 sec/batch
# Epoch: 1/20...  Training Step: 500...  Training loss: 2.2032...  0.0399 sec/batch
# Epoch: 1/20...  Training Step: 550...  Training loss: 1.8769...  0.0391 sec/batch
# Epoch: 1/20...  Training Step: 600...  Training loss: 1.8336...  0.0393 sec/batch
# Epoch: 1/20...  Training Step: 650...  Training loss: 1.7440...  0.0392 sec/batch
# Epoch: 1/20...  Training Step: 700...  Training loss: 1.8484...  0.0385 sec/batch
# Epoch: 1/20...  Training Step: 750...  Training loss: 1.9014...  0.0384 sec/batch
# Epoch: 1/20...  Training Step: 800...  Training loss: 1.9096...  0.0391 sec/batch
# Epoch: 1/20...  Training Step: 850...  Training loss: 2.0123...  0.0390 sec/batch
# Epoch: 1/20...  Training Step: 900...  Training loss: 1.8277...  0.0382 sec/batch
# Epoch: 1/20...  Training Step: 950...  Training loss: 1.8741...  0.0406 sec/batch
# Epoch: 1/20...  Training Step: 1000...  Training loss: 1.7963...  0.0390 sec/batch
# Epoch: 1/20...  Training Step: 1050...  Training loss: 1.8033...  0.0391 sec/batch
# Epoch: 1/20...  Training Step: 1100...  Training loss: 1.7767...  0.0393 sec/batch
# Epoch: 1/20...  Training Step: 1150...  Training loss: 1.8807...  0.0385 sec/batch
# Epoch: 1/20...  Training Step: 1200...  Training loss: 1.7433...  0.0388 sec/batch
# Epoch: 1/20...  Training Step: 1250...  Training loss: 1.6067...  0.0598 sec/batch
# Epoch: 1/20...  Training Step: 1300...  Training loss: 1.7242...  0.0600 sec/batch
# Epoch: 1/20...  Training Step: 1350...  Training loss: 1.6661...  0.0397 sec/batch
# Epoch: 1/20...  Training Step: 1400...  Training loss: 1.8631...  0.0388 sec/batch
# Epoch: 1/20...  Training Step: 1450...  Training loss: 1.7207...  0.0581 sec/batch
# Epoch: 1/20...  Training Step: 1500...  Training loss: 1.7667...  0.0384 sec/batch
# Epoch: 1/20...  Training Step: 1550...  Training loss: 1.6731...  0.0391 sec/batch
# Epoch: 1/20...  Training Step: 1600...  Training loss: 1.7167...  0.0386 sec/batch
# Epoch: 1/20...  Training Step: 1650...  Training loss: 1.5643...  0.0386 sec/batch
# Epoch: 1/20...  Training Step: 1700...  Training loss: 1.6606...  0.0394 sec/batch
# Epoch: 1/20...  Training Step: 1750...  Training loss: 1.7195...  0.0405 sec/batch
# Epoch: 1/20...  Training Step: 1800...  Training loss: 1.6814...  0.0381 sec/batch
# Epoch: 1/20...  Training Step: 1850...  Training loss: 1.8145...  0.0390 sec/batch
# Epoch: 1/20...  Training Step: 1900...  Training loss: 1.5333...  0.0386 sec/batch
# Epoch: 1/20...  Training Step: 1950...  Training loss: 1.5858...  0.0393 sec/batch
# Epoch: 1/20...  Training Step: 2000...  Training loss: 1.6889...  0.0384 sec/batch
# Epoch: 1/20...  Training Step: 2050...  Training loss: 1.7997...  0.0382 sec/batch
# Epoch: 1/20...  Training Step: 2100...  Training loss: 1.6202...  0.0408 sec/batch
# Epoch: 1/20...  Training Step: 2150...  Training loss: 1.6404...  0.0392 sec/batch
# Epoch: 1/20...  Training Step: 2200...  Training loss: 1.6559...  0.0384 sec/batch
# Epoch: 1/20...  Training Step: 2250...  Training loss: 1.6352...  0.0385 sec/batch
# Epoch: 1/20...  Training Step: 2300...  Training loss: 1.4619...  0.0390 sec/batch
# Epoch: 1/20...  Training Step: 2350...  Training loss: 1.7313...  0.0386 sec/batch
# Epoch: 1/20...  Training Step: 2400...  Training loss: 1.7095...  0.0388 sec/batch
# Epoch: 1/20...  Training Step: 2450...  Training loss: 1.8204...  0.0386 sec/batch
# Epoch: 1/20...  Training Step: 2500...  Training loss: 1.5769...  0.0388 sec/batch
# Epoch: 1/20...  Training Step: 2550...  Training loss: 1.6311...  0.0381 sec/batch
# Epoch: 1/20...  Training Step: 2600...  Training loss: 1.5612...  0.0388 sec/batch
# Epoch: 1/20...  Training Step: 2650...  Training loss: 1.7584...  0.0391 sec/batch
# Epoch: 1/20...  Training Step: 2700...  Training loss: 1.7028...  0.0391 sec/batch
# Epoch: 1/20...  Training Step: 2750...  Training loss: 1.5333...  0.0403 sec/batch
# Epoch: 1/20...  Training Step: 2800...  Training loss: 1.4281...  0.0388 sec/batch
# Epoch: 1/20...  Training Step: 2850...  Training loss: 1.7343...  0.0393 sec/batch
# Epoch: 1/20...  Training Step: 2900...  Training loss: 1.4330...  0.0399 sec/batch
# Epoch: 1/20...  Training Step: 2950...  Training loss: 1.3713...  0.0394 sec/batch
# Epoch: 1/20...  Training Step: 3000...  Training loss: 1.5665...  0.0384 sec/batch
# Epoch: 1/20...  Training Step: 3050...  Training loss: 1.7035...  0.0394 sec/batch
# Epoch: 1/20...  Training Step: 3100...  Training loss: 1.5459...  0.0387 sec/batch
# Epoch: 1/20...  Training Step: 3150...  Training loss: 1.4969...  0.0380 sec/batch
# Epoch: 1/20...  Training Step: 3200...  Training loss: 1.6661...  0.0393 sec/batch
# Epoch: 1/20...  Training Step: 3250...  Training loss: 1.6137...  0.0393 sec/batch
# Epoch: 1/20...  Training Step: 3300...  Training loss: 1.6392...  0.0393 sec/batch
# Epoch: 1/20...  Training Step: 3350...  Training loss: 1.4680...  0.0395 sec/batch
# Epoch: 1/20...  Training Step: 3400...  Training loss: 1.6103...  0.0388 sec/batch
# Epoch: 1/20...  Training Step: 3450...  Training loss: 1.4843...  0.0383 sec/batch
# Epoch: 1/20...  Training Step: 3500...  Training loss: 1.5104...  0.0382 sec/batch
# Epoch: 1/20...  Training Step: 3550...  Training loss: 1.6281...  0.0389 sec/batch
# Epoch: 1/20...  Training Step: 3600...  Training loss: 1.6119...  0.0398 sec/batch
# Epoch: 1/20...  Training Step: 3650...  Training loss: 1.7479...  0.0399 sec/batch
# Epoch: 1/20...  Training Step: 3700...  Training loss: 1.5098...  0.0429 sec/batch
# Epoch: 1/20...  Training Step: 3750...  Training loss: 1.6239...  0.0376 sec/batch
# Epoch: 1/20...  Training Step: 3800...  Training loss: 1.4975...  0.0383 sec/batch
# Epoch: 1/20...  Training Step: 3850...  Training loss: 1.5534...  0.0386 sec/batch
# Epoch: 1/20...  Training Step: 3900...  Training loss: 1.7199...  0.0385 sec/batch
# Epoch: 1/20...  Training Step: 3950...  Training loss: 1.4999...  0.0402 sec/batch
# Epoch: 2/20...  Training Step: 4000...  Training loss: 1.5055...  0.0390 sec/batch
# Epoch: 2/20...  Training Step: 4050...  Training loss: 1.5349...  0.0393 sec/batch
# Epoch: 2/20...  Training Step: 4100...  Training loss: 1.5186...  0.0385 sec/batch
# Epoch: 2/20...  Training Step: 4150...  Training loss: 1.3972...  0.0392 sec/batch
# Epoch: 2/20...  Training Step: 4200...  Training loss: 1.5217...  0.0393 sec/batch
# Epoch: 2/20...  Training Step: 4250...  Training loss: 1.5698...  0.0386 sec/batch
# Epoch: 2/20...  Training Step: 4300...  Training loss: 1.6320...  0.0394 sec/batch
# Epoch: 2/20...  Training Step: 4350...  Training loss: 1.5973...  0.0399 sec/batch
# Epoch: 2/20...  Training Step: 4400...  Training loss: 1.5309...  0.0391 sec/batch
# Epoch: 2/20...  Training Step: 4450...  Training loss: 1.5865...  0.0383 sec/batch
# Epoch: 2/20...  Training Step: 4500...  Training loss: 1.5471...  0.0383 sec/batch
# Epoch: 2/20...  Training Step: 4550...  Training loss: 1.6761...  0.0395 sec/batch
# Epoch: 2/20...  Training Step: 4600...  Training loss: 1.6477...  0.0388 sec/batch
# Epoch: 2/20...  Training Step: 4650...  Training loss: 1.7223...  0.0378 sec/batch
# Epoch: 2/20...  Training Step: 4700...  Training loss: 1.4316...  0.0391 sec/batch
# Epoch: 2/20...  Training Step: 4750...  Training loss: 1.6642...  0.0378 sec/batch
# Epoch: 2/20...  Training Step: 4800...  Training loss: 1.4732...  0.0384 sec/batch
# Epoch: 2/20...  Training Step: 4850...  Training loss: 1.4542...  0.0383 sec/batch
# Epoch: 2/20...  Training Step: 4900...  Training loss: 1.5234...  0.0386 sec/batch
# Epoch: 2/20...  Training Step: 4950...  Training loss: 1.4537...  0.0383 sec/batch
# Epoch: 2/20...  Training Step: 5000...  Training loss: 1.4839...  0.0390 sec/batch
# Epoch: 2/20...  Training Step: 5050...  Training loss: 1.3641...  0.0385 sec/batch
# Epoch: 2/20...  Training Step: 5100...  Training loss: 1.3873...  0.0386 sec/batch
# Epoch: 2/20...  Training Step: 5150...  Training loss: 1.4974...  0.0381 sec/batch
# Epoch: 2/20...  Training Step: 5200...  Training loss: 1.5828...  0.0390 sec/batch
# Epoch: 2/20...  Training Step: 5250...  Training loss: 1.4023...  0.0388 sec/batch
# Epoch: 2/20...  Training Step: 5300...  Training loss: 1.5987...  0.0385 sec/batch
# Epoch: 2/20...  Training Step: 5350...  Training loss: 1.4893...  0.0390 sec/batch
# Epoch: 2/20...  Training Step: 5400...  Training loss: 1.5917...  0.0390 sec/batch
# Epoch: 2/20...  Training Step: 5450...  Training loss: 1.5558...  0.0387 sec/batch
# Epoch: 2/20...  Training Step: 5500...  Training loss: 1.5678...  0.0388 sec/batch
# Epoch: 2/20...  Training Step: 5550...  Training loss: 1.5302...  0.0382 sec/batch
# Epoch: 2/20...  Training Step: 5600...  Training loss: 1.6033...  0.0387 sec/batch
# Epoch: 2/20...  Training Step: 5650...  Training loss: 1.4672...  0.0392 sec/batch
# Epoch: 2/20...  Training Step: 5700...  Training loss: 1.3850...  0.0395 sec/batch
# Epoch: 2/20...  Training Step: 5750...  Training loss: 1.5090...  0.0398 sec/batch
# Epoch: 2/20...  Training Step: 5800...  Training loss: 1.5422...  0.0401 sec/batch
# Epoch: 2/20...  Training Step: 5850...  Training loss: 1.6063...  0.0397 sec/batch
# Epoch: 2/20...  Training Step: 5900...  Training loss: 1.5180...  0.0387 sec/batch
# Epoch: 2/20...  Training Step: 5950...  Training loss: 1.4605...  0.0397 sec/batch
# Epoch: 2/20...  Training Step: 6000...  Training loss: 1.4332...  0.0388 sec/batch
# Epoch: 2/20...  Training Step: 6050...  Training loss: 1.4286...  0.0389 sec/batch
# Epoch: 2/20...  Training Step: 6100...  Training loss: 1.6136...  0.0387 sec/batch
# Epoch: 2/20...  Training Step: 6150...  Training loss: 1.5094...  0.0378 sec/batch
# Epoch: 2/20...  Training Step: 6200...  Training loss: 1.5475...  0.0381 sec/batch
# Epoch: 2/20...  Training Step: 6250...  Training loss: 1.4341...  0.0380 sec/batch
# Epoch: 2/20...  Training Step: 6300...  Training loss: 1.4679...  0.0393 sec/batch
# Epoch: 2/20...  Training Step: 6350...  Training loss: 1.5030...  0.0393 sec/batch
# Epoch: 2/20...  Training Step: 6400...  Training loss: 1.4295...  0.0386 sec/batch
# Epoch: 2/20...  Training Step: 6450...  Training loss: 1.5367...  0.0388 sec/batch
# Epoch: 2/20...  Training Step: 6500...  Training loss: 1.4234...  0.0412 sec/batch
# Epoch: 2/20...  Training Step: 6550...  Training loss: 1.5507...  0.0408 sec/batch
# Epoch: 2/20...  Training Step: 6600...  Training loss: 1.6588...  0.0418 sec/batch
# Epoch: 2/20...  Training Step: 6650...  Training loss: 1.3336...  0.0385 sec/batch
# Epoch: 2/20...  Training Step: 6700...  Training loss: 1.4018...  0.0395 sec/batch
# Epoch: 2/20...  Training Step: 6750...  Training loss: 1.3813...  0.0392 sec/batch
# Epoch: 2/20...  Training Step: 6800...  Training loss: 1.5097...  0.0380 sec/batch
# Epoch: 2/20...  Training Step: 6850...  Training loss: 1.4569...  0.0382 sec/batch
# Epoch: 2/20...  Training Step: 6900...  Training loss: 1.3844...  0.0391 sec/batch
# Epoch: 2/20...  Training Step: 6950...  Training loss: 1.6759...  0.0394 sec/batch
# Epoch: 2/20...  Training Step: 7000...  Training loss: 1.4298...  0.0390 sec/batch
# Epoch: 2/20...  Training Step: 7050...  Training loss: 1.4959...  0.0391 sec/batch
# Epoch: 2/20...  Training Step: 7100...  Training loss: 1.4008...  0.0391 sec/batch
# Epoch: 2/20...  Training Step: 7150...  Training loss: 1.4430...  0.0393 sec/batch
# Epoch: 2/20...  Training Step: 7200...  Training loss: 1.5657...  0.0414 sec/batch
# Epoch: 2/20...  Training Step: 7250...  Training loss: 1.4016...  0.0386 sec/batch
# Epoch: 2/20...  Training Step: 7300...  Training loss: 1.5909...  0.0390 sec/batch
# Epoch: 2/20...  Training Step: 7350...  Training loss: 1.4346...  0.0386 sec/batch
# Epoch: 2/20...  Training Step: 7400...  Training loss: 1.3420...  0.0386 sec/batch
# Epoch: 2/20...  Training Step: 7450...  Training loss: 1.3025...  0.0396 sec/batch
# Epoch: 2/20...  Training Step: 7500...  Training loss: 1.3760...  0.0387 sec/batch
# Epoch: 2/20...  Training Step: 7550...  Training loss: 1.3869...  0.0383 sec/batch
# Epoch: 2/20...  Training Step: 7600...  Training loss: 1.4741...  0.0392 sec/batch
# Epoch: 2/20...  Training Step: 7650...  Training loss: 1.6529...  0.0390 sec/batch
# Epoch: 2/20...  Training Step: 7700...  Training loss: 1.6450...  0.0397 sec/batch
# Epoch: 2/20...  Training Step: 7750...  Training loss: 1.6746...  0.0385 sec/batch
# Epoch: 2/20...  Training Step: 7800...  Training loss: 1.4682...  0.0397 sec/batch
# Epoch: 2/20...  Training Step: 7850...  Training loss: 1.4860...  0.0391 sec/batch
# Epoch: 2/20...  Training Step: 7900...  Training loss: 1.5470...  0.0390 sec/batch
# Epoch: 3/20...  Training Step: 7950...  Training loss: 1.5197...  0.0384 sec/batch
# Epoch: 3/20...  Training Step: 8000...  Training loss: 1.4777...  0.0390 sec/batch
# Epoch: 3/20...  Training Step: 8050...  Training loss: 1.4502...  0.0382 sec/batch
# Epoch: 3/20...  Training Step: 8100...  Training loss: 1.6550...  0.0396 sec/batch
# Epoch: 3/20...  Training Step: 8150...  Training loss: 1.4401...  0.0390 sec/batch
# Epoch: 3/20...  Training Step: 8200...  Training loss: 1.3929...  0.0386 sec/batch
# Epoch: 3/20...  Training Step: 8250...  Training loss: 1.5989...  0.0376 sec/batch
# Epoch: 3/20...  Training Step: 8300...  Training loss: 1.5424...  0.0391 sec/batch
# Epoch: 3/20...  Training Step: 8350...  Training loss: 1.4662...  0.0390 sec/batch
# Epoch: 3/20...  Training Step: 8400...  Training loss: 1.6035...  0.0382 sec/batch
# Epoch: 3/20...  Training Step: 8450...  Training loss: 1.5669...  0.0389 sec/batch
# Epoch: 3/20...  Training Step: 8500...  Training loss: 1.4835...  0.0392 sec/batch
# Epoch: 3/20...  Training Step: 8550...  Training loss: 1.4218...  0.0386 sec/batch
# Epoch: 3/20...  Training Step: 8600...  Training loss: 1.4415...  0.0387 sec/batch
# Epoch: 3/20...  Training Step: 8650...  Training loss: 1.5470...  0.0385 sec/batch
# Epoch: 3/20...  Training Step: 8700...  Training loss: 1.3798...  0.0385 sec/batch
# Epoch: 3/20...  Training Step: 8750...  Training loss: 1.4328...  0.0389 sec/batch
# Epoch: 3/20...  Training Step: 8800...  Training loss: 1.5871...  0.0387 sec/batch
# Epoch: 3/20...  Training Step: 8850...  Training loss: 1.4832...  0.0382 sec/batch
# Epoch: 3/20...  Training Step: 8900...  Training loss: 1.5339...  0.0392 sec/batch
# Epoch: 3/20...  Training Step: 8950...  Training loss: 1.5163...  0.0390 sec/batch
# Epoch: 3/20...  Training Step: 9000...  Training loss: 1.4224...  0.0384 sec/batch
# Epoch: 3/20...  Training Step: 9050...  Training loss: 1.3317...  0.0392 sec/batch
# Epoch: 3/20...  Training Step: 9100...  Training loss: 1.3138...  0.0400 sec/batch
# Epoch: 3/20...  Training Step: 9150...  Training loss: 1.4339...  0.0391 sec/batch
# Epoch: 3/20...  Training Step: 9200...  Training loss: 1.4119...  0.0385 sec/batch
# Epoch: 3/20...  Training Step: 9250...  Training loss: 1.4354...  0.0390 sec/batch
# Epoch: 3/20...  Training Step: 9300...  Training loss: 1.3297...  0.0386 sec/batch
# Epoch: 3/20...  Training Step: 9350...  Training loss: 1.4897...  0.0387 sec/batch
# Epoch: 3/20...  Training Step: 9400...  Training loss: 1.5348...  0.0391 sec/batch
# Epoch: 3/20...  Training Step: 9450...  Training loss: 1.3648...  0.0377 sec/batch
# Epoch: 3/20...  Training Step: 9500...  Training loss: 1.5332...  0.0392 sec/batch
# Epoch: 3/20...  Training Step: 9550...  Training loss: 1.5547...  0.0386 sec/batch
# Epoch: 3/20...  Training Step: 9600...  Training loss: 1.3014...  0.0388 sec/batch
# Epoch: 3/20...  Training Step: 9650...  Training loss: 1.4082...  0.0383 sec/batch
# Epoch: 3/20...  Training Step: 9700...  Training loss: 1.4120...  0.0389 sec/batch
# Epoch: 3/20...  Training Step: 9750...  Training loss: 1.3019...  0.0395 sec/batch
# Epoch: 3/20...  Training Step: 9800...  Training loss: 1.5535...  0.0391 sec/batch
# Epoch: 3/20...  Training Step: 9850...  Training loss: 1.3838...  0.0392 sec/batch
# Epoch: 3/20...  Training Step: 9900...  Training loss: 1.5214...  0.0396 sec/batch
# Epoch: 3/20...  Training Step: 9950...  Training loss: 1.4703...  0.0381 sec/batch
# Epoch: 3/20...  Training Step: 10000...  Training loss: 1.4073...  0.0385 sec/batch
# Epoch: 3/20...  Training Step: 10050...  Training loss: 1.4322...  0.0381 sec/batch
# Epoch: 3/20...  Training Step: 10100...  Training loss: 1.4768...  0.0390 sec/batch
# Epoch: 3/20...  Training Step: 10150...  Training loss: 1.5352...  0.0390 sec/batch
# Epoch: 3/20...  Training Step: 10200...  Training loss: 1.6138...  0.0402 sec/batch
# Epoch: 3/20...  Training Step: 10250...  Training loss: 1.4385...  0.0393 sec/batch
# Epoch: 3/20...  Training Step: 10300...  Training loss: 1.5677...  0.0389 sec/batch
# Epoch: 3/20...  Training Step: 10350...  Training loss: 1.4220...  0.0382 sec/batch
# Epoch: 3/20...  Training Step: 10400...  Training loss: 1.5159...  0.0395 sec/batch
# Epoch: 3/20...  Training Step: 10450...  Training loss: 1.4192...  0.0391 sec/batch
# Epoch: 3/20...  Training Step: 10500...  Training loss: 1.3046...  0.0398 sec/batch
# Epoch: 3/20...  Training Step: 10550...  Training loss: 1.4789...  0.0378 sec/batch
# Epoch: 3/20...  Training Step: 10600...  Training loss: 1.4537...  0.0396 sec/batch
# Epoch: 3/20...  Training Step: 10650...  Training loss: 1.4092...  0.0391 sec/batch
# Epoch: 3/20...  Training Step: 10700...  Training loss: 1.4476...  0.0392 sec/batch
# Epoch: 3/20...  Training Step: 10750...  Training loss: 1.5059...  0.0394 sec/batch
# Epoch: 3/20...  Training Step: 10800...  Training loss: 1.4022...  0.0381 sec/batch
# Epoch: 3/20...  Training Step: 10850...  Training loss: 1.4315...  0.0397 sec/batch
# Epoch: 3/20...  Training Step: 10900...  Training loss: 1.4673...  0.0388 sec/batch
# Epoch: 3/20...  Training Step: 10950...  Training loss: 1.5519...  0.0383 sec/batch
# Epoch: 3/20...  Training Step: 11000...  Training loss: 1.4098...  0.0383 sec/batch
# Epoch: 3/20...  Training Step: 11050...  Training loss: 1.3937...  0.0387 sec/batch
# Epoch: 3/20...  Training Step: 11100...  Training loss: 1.3500...  0.0389 sec/batch
# Epoch: 3/20...  Training Step: 11150...  Training loss: 1.3732...  0.0387 sec/batch
# Epoch: 3/20...  Training Step: 11200...  Training loss: 1.3687...  0.0397 sec/batch
# Epoch: 3/20...  Training Step: 11250...  Training loss: 1.4558...  0.0389 sec/batch
# Epoch: 3/20...  Training Step: 11300...  Training loss: 1.3818...  0.0405 sec/batch
# Epoch: 3/20...  Training Step: 11350...  Training loss: 1.4830...  0.0393 sec/batch
# Epoch: 3/20...  Training Step: 11400...  Training loss: 1.4233...  0.0384 sec/batch
# Epoch: 3/20...  Training Step: 11450...  Training loss: 1.3957...  0.0410 sec/batch
# Epoch: 3/20...  Training Step: 11500...  Training loss: 1.3587...  0.0398 sec/batch
# Epoch: 3/20...  Training Step: 11550...  Training loss: 1.5313...  0.0413 sec/batch
# Epoch: 3/20...  Training Step: 11600...  Training loss: 1.5251...  0.0406 sec/batch
# Epoch: 3/20...  Training Step: 11650...  Training loss: 1.3823...  0.0393 sec/batch
# Epoch: 3/20...  Training Step: 11700...  Training loss: 1.3281...  0.0398 sec/batch
# Epoch: 3/20...  Training Step: 11750...  Training loss: 1.5429...  0.0385 sec/batch
# Epoch: 3/20...  Training Step: 11800...  Training loss: 1.5312...  0.0396 sec/batch
# Epoch: 3/20...  Training Step: 11850...  Training loss: 1.7617...  0.0384 sec/batch
# Epoch: 3/20...  Training Step: 11900...  Training loss: 1.4632...  0.0395 sec/batch
# Epoch: 4/20...  Training Step: 11950...  Training loss: 1.4807...  0.0384 sec/batch
# Epoch: 4/20...  Training Step: 12000...  Training loss: 1.3947...  0.0385 sec/batch
# Epoch: 4/20...  Training Step: 12050...  Training loss: 1.4177...  0.0390 sec/batch
# Epoch: 4/20...  Training Step: 12100...  Training loss: 1.4497...  0.0390 sec/batch
# Epoch: 4/20...  Training Step: 12150...  Training loss: 1.5204...  0.0396 sec/batch
# Epoch: 4/20...  Training Step: 12200...  Training loss: 1.3439...  0.0387 sec/batch
# Epoch: 4/20...  Training Step: 12250...  Training loss: 1.4083...  0.0384 sec/batch
# Epoch: 4/20...  Training Step: 12300...  Training loss: 1.3532...  0.0388 sec/batch
# Epoch: 4/20...  Training Step: 12350...  Training loss: 1.4744...  0.0387 sec/batch
# Epoch: 4/20...  Training Step: 12400...  Training loss: 1.4332...  0.0386 sec/batch
# Epoch: 4/20...  Training Step: 12450...  Training loss: 1.2339...  0.0393 sec/batch
# Epoch: 4/20...  Training Step: 12500...  Training loss: 1.5411...  0.0392 sec/batch
# Epoch: 4/20...  Training Step: 12550...  Training loss: 1.2954...  0.0391 sec/batch
# Epoch: 4/20...  Training Step: 12600...  Training loss: 1.3418...  0.0395 sec/batch
# Epoch: 4/20...  Training Step: 12650...  Training loss: 1.3927...  0.0385 sec/batch
# Epoch: 4/20...  Training Step: 12700...  Training loss: 1.3811...  0.0393 sec/batch
# Epoch: 4/20...  Training Step: 12750...  Training loss: 1.4040...  0.0384 sec/batch
# Epoch: 4/20...  Training Step: 12800...  Training loss: 1.4576...  0.0385 sec/batch
# Epoch: 4/20...  Training Step: 12850...  Training loss: 1.3052...  0.0393 sec/batch
# Epoch: 4/20...  Training Step: 12900...  Training loss: 1.3126...  0.0389 sec/batch
# Epoch: 4/20...  Training Step: 12950...  Training loss: 1.3837...  0.0383 sec/batch
# Epoch: 4/20...  Training Step: 13000...  Training loss: 1.5727...  0.0382 sec/batch
# Epoch: 4/20...  Training Step: 13050...  Training loss: 1.5371...  0.0402 sec/batch
# Epoch: 4/20...  Training Step: 13100...  Training loss: 1.3594...  0.0385 sec/batch
# Epoch: 4/20...  Training Step: 13150...  Training loss: 1.3365...  0.0390 sec/batch
# Epoch: 4/20...  Training Step: 13200...  Training loss: 1.6300...  0.0400 sec/batch
# Epoch: 4/20...  Training Step: 13250...  Training loss: 1.4289...  0.0390 sec/batch
# Epoch: 4/20...  Training Step: 13300...  Training loss: 1.3805...  0.0394 sec/batch
# Epoch: 4/20...  Training Step: 13350...  Training loss: 1.3796...  0.0389 sec/batch
# Epoch: 4/20...  Training Step: 13400...  Training loss: 1.4774...  0.0407 sec/batch
# Epoch: 4/20...  Training Step: 13450...  Training loss: 1.4803...  0.0379 sec/batch
# Epoch: 4/20...  Training Step: 13500...  Training loss: 1.4671...  0.0380 sec/batch
# Epoch: 4/20...  Training Step: 13550...  Training loss: 1.5215...  0.0388 sec/batch
# Epoch: 4/20...  Training Step: 13600...  Training loss: 1.3520...  0.0396 sec/batch
# Epoch: 4/20...  Training Step: 13650...  Training loss: 1.3859...  0.0390 sec/batch
# Epoch: 4/20...  Training Step: 13700...  Training loss: 1.3843...  0.0385 sec/batch
# Epoch: 4/20...  Training Step: 13750...  Training loss: 1.4543...  0.0396 sec/batch
# Epoch: 4/20...  Training Step: 13800...  Training loss: 1.4199...  0.0378 sec/batch
# Epoch: 4/20...  Training Step: 13850...  Training loss: 1.6688...  0.0378 sec/batch
# Epoch: 4/20...  Training Step: 13900...  Training loss: 1.4521...  0.0383 sec/batch
# Epoch: 4/20...  Training Step: 13950...  Training loss: 1.4474...  0.0387 sec/batch
# Epoch: 4/20...  Training Step: 14000...  Training loss: 1.3832...  0.0380 sec/batch
# Epoch: 4/20...  Training Step: 14050...  Training loss: 1.4104...  0.0386 sec/batch
# Epoch: 4/20...  Training Step: 14100...  Training loss: 1.4100...  0.0393 sec/batch
# Epoch: 4/20...  Training Step: 14150...  Training loss: 1.5841...  0.0387 sec/batch
# Epoch: 4/20...  Training Step: 14200...  Training loss: 1.4108...  0.0391 sec/batch
# Epoch: 4/20...  Training Step: 14250...  Training loss: 1.5864...  0.0393 sec/batch
# Epoch: 4/20...  Training Step: 14300...  Training loss: 1.5368...  0.0414 sec/batch
# Epoch: 4/20...  Training Step: 14350...  Training loss: 1.3880...  0.0406 sec/batch
# Epoch: 4/20...  Training Step: 14400...  Training loss: 1.4434...  0.0391 sec/batch
# Epoch: 4/20...  Training Step: 14450...  Training loss: 1.4802...  0.0505 sec/batch
# Epoch: 4/20...  Training Step: 14500...  Training loss: 1.4737...  0.0404 sec/batch
# Epoch: 4/20...  Training Step: 14550...  Training loss: 1.2886...  0.0418 sec/batch
# Epoch: 4/20...  Training Step: 14600...  Training loss: 1.4174...  0.0392 sec/batch
# Epoch: 4/20...  Training Step: 14650...  Training loss: 1.3408...  0.0395 sec/batch
# Epoch: 4/20...  Training Step: 14700...  Training loss: 1.3038...  0.0392 sec/batch
# Epoch: 4/20...  Training Step: 14750...  Training loss: 1.4320...  0.0385 sec/batch
# Epoch: 4/20...  Training Step: 14800...  Training loss: 1.3248...  0.0388 sec/batch
# Epoch: 4/20...  Training Step: 14850...  Training loss: 1.4357...  0.0393 sec/batch
# Epoch: 4/20...  Training Step: 14900...  Training loss: 1.4442...  0.0384 sec/batch
# Epoch: 4/20...  Training Step: 14950...  Training loss: 1.4849...  0.0403 sec/batch
# Epoch: 4/20...  Training Step: 15000...  Training loss: 1.4100...  0.0386 sec/batch
# Epoch: 4/20...  Training Step: 15050...  Training loss: 1.5255...  0.0367 sec/batch
# Epoch: 4/20...  Training Step: 15100...  Training loss: 1.3065...  0.0384 sec/batch
# Epoch: 4/20...  Training Step: 15150...  Training loss: 1.3663...  0.0384 sec/batch
# Epoch: 4/20...  Training Step: 15200...  Training loss: 1.5033...  0.0389 sec/batch
# Epoch: 4/20...  Training Step: 15250...  Training loss: 1.3802...  0.0395 sec/batch
# Epoch: 4/20...  Training Step: 15300...  Training loss: 1.3574...  0.0387 sec/batch
# Epoch: 4/20...  Training Step: 15350...  Training loss: 1.3873...  0.0399 sec/batch
# Epoch: 4/20...  Training Step: 15400...  Training loss: 1.5673...  0.0385 sec/batch
# Epoch: 4/20...  Training Step: 15450...  Training loss: 1.3927...  0.0388 sec/batch
# Epoch: 4/20...  Training Step: 15500...  Training loss: 1.3630...  0.0395 sec/batch
# Epoch: 4/20...  Training Step: 15550...  Training loss: 1.3725...  0.0396 sec/batch
# Epoch: 4/20...  Training Step: 15600...  Training loss: 1.4086...  0.0397 sec/batch
# Epoch: 4/20...  Training Step: 15650...  Training loss: 1.3738...  0.0383 sec/batch
# Epoch: 4/20...  Training Step: 15700...  Training loss: 1.3920...  0.0391 sec/batch
# Epoch: 4/20...  Training Step: 15750...  Training loss: 1.5160...  0.0390 sec/batch
# Epoch: 4/20...  Training Step: 15800...  Training loss: 1.5211...  0.0395 sec/batch
# Epoch: 4/20...  Training Step: 15850...  Training loss: 1.4348...  0.0387 sec/batch
# Epoch: 5/20...  Training Step: 15900...  Training loss: 1.4916...  0.0394 sec/batch
# Epoch: 5/20...  Training Step: 15950...  Training loss: 1.4508...  0.0394 sec/batch
# Epoch: 5/20...  Training Step: 16000...  Training loss: 1.3145...  0.0397 sec/batch
# Epoch: 5/20...  Training Step: 16050...  Training loss: 1.4225...  0.0400 sec/batch
# Epoch: 5/20...  Training Step: 16100...  Training loss: 1.3764...  0.0387 sec/batch
# Epoch: 5/20...  Training Step: 16150...  Training loss: 1.4483...  0.0385 sec/batch
# Epoch: 5/20...  Training Step: 16200...  Training loss: 1.4529...  0.0383 sec/batch
# Epoch: 5/20...  Training Step: 16250...  Training loss: 1.4366...  0.0389 sec/batch
# Epoch: 5/20...  Training Step: 16300...  Training loss: 1.4788...  0.0391 sec/batch
# Epoch: 5/20...  Training Step: 16350...  Training loss: 1.4750...  0.0402 sec/batch
# Epoch: 5/20...  Training Step: 16400...  Training loss: 1.3539...  0.0389 sec/batch
# Epoch: 5/20...  Training Step: 16450...  Training loss: 1.4491...  0.0388 sec/batch
# Epoch: 5/20...  Training Step: 16500...  Training loss: 1.2497...  0.0391 sec/batch
# Epoch: 5/20...  Training Step: 16550...  Training loss: 1.4478...  0.0390 sec/batch
# Epoch: 5/20...  Training Step: 16600...  Training loss: 1.3936...  0.0386 sec/batch
# Epoch: 5/20...  Training Step: 16650...  Training loss: 1.3964...  0.0387 sec/batch
# Epoch: 5/20...  Training Step: 16700...  Training loss: 1.4271...  0.0391 sec/batch
# Epoch: 5/20...  Training Step: 16750...  Training loss: 1.3832...  0.0392 sec/batch
# Epoch: 5/20...  Training Step: 16800...  Training loss: 1.3233...  0.0387 sec/batch
# Epoch: 5/20...  Training Step: 16850...  Training loss: 1.3441...  0.0396 sec/batch
# Epoch: 5/20...  Training Step: 16900...  Training loss: 1.2197...  0.0374 sec/batch
# Epoch: 5/20...  Training Step: 16950...  Training loss: 1.2950...  0.0391 sec/batch
# Epoch: 5/20...  Training Step: 17000...  Training loss: 1.2291...  0.0391 sec/batch
# Epoch: 5/20...  Training Step: 17050...  Training loss: 1.3361...  0.0391 sec/batch
# Epoch: 5/20...  Training Step: 17100...  Training loss: 1.2971...  0.0391 sec/batch
# Epoch: 5/20...  Training Step: 17150...  Training loss: 1.3910...  0.0380 sec/batch
# Epoch: 5/20...  Training Step: 17200...  Training loss: 1.4609...  0.0394 sec/batch
# Epoch: 5/20...  Training Step: 17250...  Training loss: 1.4314...  0.0401 sec/batch
# Epoch: 5/20...  Training Step: 17300...  Training loss: 1.4785...  0.0394 sec/batch
# Epoch: 5/20...  Training Step: 17350...  Training loss: 1.3600...  0.0386 sec/batch
# Epoch: 5/20...  Training Step: 17400...  Training loss: 1.3533...  0.0384 sec/batch
# Epoch: 5/20...  Training Step: 17450...  Training loss: 1.4257...  0.0393 sec/batch
# Epoch: 5/20...  Training Step: 17500...  Training loss: 1.4803...  0.0379 sec/batch
# Epoch: 5/20...  Training Step: 17550...  Training loss: 1.4883...  0.0392 sec/batch
# Epoch: 5/20...  Training Step: 17600...  Training loss: 1.3892...  0.0388 sec/batch
# Epoch: 5/20...  Training Step: 17650...  Training loss: 1.5075...  0.0392 sec/batch
# Epoch: 5/20...  Training Step: 17700...  Training loss: 1.3822...  0.0395 sec/batch
# Epoch: 5/20...  Training Step: 17750...  Training loss: 1.2053...  0.0382 sec/batch
# Epoch: 5/20...  Training Step: 17800...  Training loss: 1.4012...  0.0384 sec/batch
# Epoch: 5/20...  Training Step: 17850...  Training loss: 1.3750...  0.0392 sec/batch
# Epoch: 5/20...  Training Step: 17900...  Training loss: 1.3284...  0.0388 sec/batch
# Epoch: 5/20...  Training Step: 17950...  Training loss: 1.3616...  0.0382 sec/batch
# Epoch: 5/20...  Training Step: 18000...  Training loss: 1.2013...  0.0394 sec/batch
# Epoch: 5/20...  Training Step: 18050...  Training loss: 1.3261...  0.0395 sec/batch
# Epoch: 5/20...  Training Step: 18100...  Training loss: 1.4191...  0.0382 sec/batch
# Epoch: 5/20...  Training Step: 18150...  Training loss: 1.2903...  0.0397 sec/batch
# Epoch: 5/20...  Training Step: 18200...  Training loss: 1.3031...  0.0404 sec/batch
# Epoch: 5/20...  Training Step: 18250...  Training loss: 1.2962...  0.0394 sec/batch
# Epoch: 5/20...  Training Step: 18300...  Training loss: 1.5194...  0.0377 sec/batch
# Epoch: 5/20...  Training Step: 18350...  Training loss: 1.3823...  0.0393 sec/batch
# Epoch: 5/20...  Training Step: 18400...  Training loss: 1.4549...  0.0388 sec/batch
# Epoch: 5/20...  Training Step: 18450...  Training loss: 1.2963...  0.0384 sec/batch
# Epoch: 5/20...  Training Step: 18500...  Training loss: 1.2074...  0.0385 sec/batch
# Epoch: 5/20...  Training Step: 18550...  Training loss: 1.3906...  0.0390 sec/batch
# Epoch: 5/20...  Training Step: 18600...  Training loss: 1.3099...  0.0388 sec/batch
# Epoch: 5/20...  Training Step: 18650...  Training loss: 1.3992...  0.0381 sec/batch
# Epoch: 5/20...  Training Step: 18700...  Training loss: 1.5123...  0.0385 sec/batch
# Epoch: 5/20...  Training Step: 18750...  Training loss: 1.3285...  0.0389 sec/batch
# Epoch: 5/20...  Training Step: 18800...  Training loss: 1.5323...  0.0392 sec/batch
# Epoch: 5/20...  Training Step: 18850...  Training loss: 1.3232...  0.0394 sec/batch
# Epoch: 5/20...  Training Step: 18900...  Training loss: 1.5109...  0.0387 sec/batch
# Epoch: 5/20...  Training Step: 18950...  Training loss: 1.3808...  0.0394 sec/batch
# Epoch: 5/20...  Training Step: 19000...  Training loss: 1.3098...  0.0392 sec/batch
# Epoch: 5/20...  Training Step: 19050...  Training loss: 1.3475...  0.0395 sec/batch
# Epoch: 5/20...  Training Step: 19100...  Training loss: 1.3900...  0.0377 sec/batch
# Epoch: 5/20...  Training Step: 19150...  Training loss: 1.4488...  0.0397 sec/batch
# Epoch: 5/20...  Training Step: 19200...  Training loss: 1.3606...  0.0397 sec/batch
# Epoch: 5/20...  Training Step: 19250...  Training loss: 1.3059...  0.0388 sec/batch
# Epoch: 5/20...  Training Step: 19300...  Training loss: 1.5857...  0.0389 sec/batch
# Epoch: 5/20...  Training Step: 19350...  Training loss: 1.3758...  0.0378 sec/batch
# Epoch: 5/20...  Training Step: 19400...  Training loss: 1.3665...  0.0388 sec/batch
# Epoch: 5/20...  Training Step: 19450...  Training loss: 1.1578...  0.0407 sec/batch
# Epoch: 5/20...  Training Step: 19500...  Training loss: 1.2794...  0.0394 sec/batch
# Epoch: 5/20...  Training Step: 19550...  Training loss: 1.4219...  0.0388 sec/batch
# Epoch: 5/20...  Training Step: 19600...  Training loss: 1.3630...  0.0404 sec/batch
# Epoch: 5/20...  Training Step: 19650...  Training loss: 1.3396...  0.0394 sec/batch
# Epoch: 5/20...  Training Step: 19700...  Training loss: 1.6089...  0.0386 sec/batch
# Epoch: 5/20...  Training Step: 19750...  Training loss: 1.4230...  0.0400 sec/batch
# Epoch: 5/20...  Training Step: 19800...  Training loss: 1.6403...  0.0387 sec/batch
# Epoch: 5/20...  Training Step: 19850...  Training loss: 1.6291...  0.0396 sec/batch
# Epoch: 6/20...  Training Step: 19900...  Training loss: 1.5198...  0.0387 sec/batch
# Epoch: 6/20...  Training Step: 19950...  Training loss: 1.3826...  0.0362 sec/batch
# Epoch: 6/20...  Training Step: 20000...  Training loss: 1.2326...  0.0384 sec/batch
# Epoch: 6/20...  Training Step: 20050...  Training loss: 1.3726...  0.0384 sec/batch
# Epoch: 6/20...  Training Step: 20100...  Training loss: 1.3923...  0.0397 sec/batch
# Epoch: 6/20...  Training Step: 20150...  Training loss: 1.2094...  0.0389 sec/batch
# Epoch: 6/20...  Training Step: 20200...  Training loss: 1.3808...  0.0390 sec/batch
# Epoch: 6/20...  Training Step: 20250...  Training loss: 1.4377...  0.0401 sec/batch
# Epoch: 6/20...  Training Step: 20300...  Training loss: 1.4728...  0.0399 sec/batch
# Epoch: 6/20...  Training Step: 20350...  Training loss: 1.4765...  0.0391 sec/batch
# Epoch: 6/20...  Training Step: 20400...  Training loss: 1.2300...  0.0386 sec/batch
# Epoch: 6/20...  Training Step: 20450...  Training loss: 1.2697...  0.0390 sec/batch
# Epoch: 6/20...  Training Step: 20500...  Training loss: 1.1656...  0.0389 sec/batch
# Epoch: 6/20...  Training Step: 20550...  Training loss: 1.2842...  0.0388 sec/batch
# Epoch: 6/20...  Training Step: 20600...  Training loss: 1.3439...  0.0394 sec/batch
# Epoch: 6/20...  Training Step: 20650...  Training loss: 1.4134...  0.0398 sec/batch
# Epoch: 6/20...  Training Step: 20700...  Training loss: 1.4634...  0.0387 sec/batch
# Epoch: 6/20...  Training Step: 20750...  Training loss: 1.4546...  0.0391 sec/batch
# Epoch: 6/20...  Training Step: 20800...  Training loss: 1.3906...  0.0388 sec/batch
# Epoch: 6/20...  Training Step: 20850...  Training loss: 1.3705...  0.0392 sec/batch
# Epoch: 6/20...  Training Step: 20900...  Training loss: 1.4263...  0.0396 sec/batch
# Epoch: 6/20...  Training Step: 20950...  Training loss: 1.3572...  0.0385 sec/batch
# Epoch: 6/20...  Training Step: 21000...  Training loss: 1.3629...  0.0380 sec/batch
# Epoch: 6/20...  Training Step: 21050...  Training loss: 1.2674...  0.0395 sec/batch
# Epoch: 6/20...  Training Step: 21100...  Training loss: 1.2210...  0.0386 sec/batch
# Epoch: 6/20...  Training Step: 21150...  Training loss: 1.2624...  0.0395 sec/batch
# Epoch: 6/20...  Training Step: 21200...  Training loss: 1.2757...  0.0384 sec/batch
# Epoch: 6/20...  Training Step: 21250...  Training loss: 1.4952...  0.0391 sec/batch
# Epoch: 6/20...  Training Step: 21300...  Training loss: 1.3748...  0.0391 sec/batch
# Epoch: 6/20...  Training Step: 21350...  Training loss: 1.4422...  0.0392 sec/batch
# Epoch: 6/20...  Training Step: 21400...  Training loss: 1.2892...  0.0395 sec/batch
# Epoch: 6/20...  Training Step: 21450...  Training loss: 1.4326...  0.0388 sec/batch
# Epoch: 6/20...  Training Step: 21500...  Training loss: 1.2615...  0.0386 sec/batch
# Epoch: 6/20...  Training Step: 21550...  Training loss: 1.3937...  0.0386 sec/batch
# Epoch: 6/20...  Training Step: 21600...  Training loss: 1.3724...  0.0401 sec/batch
# Epoch: 6/20...  Training Step: 21650...  Training loss: 1.4067...  0.0393 sec/batch
# Epoch: 6/20...  Training Step: 21700...  Training loss: 1.4375...  0.0400 sec/batch
# Epoch: 6/20...  Training Step: 21750...  Training loss: 1.1658...  0.0400 sec/batch
# Epoch: 6/20...  Training Step: 21800...  Training loss: 1.2740...  0.0391 sec/batch
# Epoch: 6/20...  Training Step: 21850...  Training loss: 1.3945...  0.0390 sec/batch
# Epoch: 6/20...  Training Step: 21900...  Training loss: 1.4928...  0.0388 sec/batch
# Epoch: 6/20...  Training Step: 21950...  Training loss: 1.3593...  0.0395 sec/batch
# Epoch: 6/20...  Training Step: 22000...  Training loss: 1.3788...  0.0392 sec/batch
# Epoch: 6/20...  Training Step: 22050...  Training loss: 1.3554...  0.0391 sec/batch
# Epoch: 6/20...  Training Step: 22100...  Training loss: 1.3855...  0.0396 sec/batch
# Epoch: 6/20...  Training Step: 22150...  Training loss: 1.3023...  0.0384 sec/batch
# Epoch: 6/20...  Training Step: 22200...  Training loss: 1.4639...  0.0383 sec/batch
# Epoch: 6/20...  Training Step: 22250...  Training loss: 1.4848...  0.0397 sec/batch
# Epoch: 6/20...  Training Step: 22300...  Training loss: 1.4890...  0.0393 sec/batch
# Epoch: 6/20...  Training Step: 22350...  Training loss: 1.3398...  0.0381 sec/batch
# Epoch: 6/20...  Training Step: 22400...  Training loss: 1.4565...  0.0381 sec/batch
# Epoch: 6/20...  Training Step: 22450...  Training loss: 1.3366...  0.0383 sec/batch
# Epoch: 6/20...  Training Step: 22500...  Training loss: 1.5141...  0.0391 sec/batch
# Epoch: 6/20...  Training Step: 22550...  Training loss: 1.4629...  0.0463 sec/batch
# Epoch: 6/20...  Training Step: 22600...  Training loss: 1.3203...  0.0392 sec/batch
# Epoch: 6/20...  Training Step: 22650...  Training loss: 1.2223...  0.0391 sec/batch
# Epoch: 6/20...  Training Step: 22700...  Training loss: 1.5432...  0.0399 sec/batch
# Epoch: 6/20...  Training Step: 22750...  Training loss: 1.2815...  0.0398 sec/batch
# Epoch: 6/20...  Training Step: 22800...  Training loss: 1.1852...  0.0387 sec/batch
# Epoch: 6/20...  Training Step: 22850...  Training loss: 1.3125...  0.0401 sec/batch
# Epoch: 6/20...  Training Step: 22900...  Training loss: 1.4487...  0.0401 sec/batch
# Epoch: 6/20...  Training Step: 22950...  Training loss: 1.3565...  0.0395 sec/batch
# Epoch: 6/20...  Training Step: 23000...  Training loss: 1.2234...  0.0362 sec/batch
# Epoch: 6/20...  Training Step: 23050...  Training loss: 1.5230...  0.0387 sec/batch
# Epoch: 6/20...  Training Step: 23100...  Training loss: 1.4275...  0.0382 sec/batch
# Epoch: 6/20...  Training Step: 23150...  Training loss: 1.3653...  0.0387 sec/batch
# Epoch: 6/20...  Training Step: 23200...  Training loss: 1.2663...  0.0383 sec/batch
# Epoch: 6/20...  Training Step: 23250...  Training loss: 1.4289...  0.0375 sec/batch
# Epoch: 6/20...  Training Step: 23300...  Training loss: 1.3033...  0.0406 sec/batch
# Epoch: 6/20...  Training Step: 23350...  Training loss: 1.2828...  0.0402 sec/batch
# Epoch: 6/20...  Training Step: 23400...  Training loss: 1.4325...  0.0416 sec/batch
# Epoch: 6/20...  Training Step: 23450...  Training loss: 1.4001...  0.0387 sec/batch
# Epoch: 6/20...  Training Step: 23500...  Training loss: 1.5382...  0.0390 sec/batch
# Epoch: 6/20...  Training Step: 23550...  Training loss: 1.2345...  0.0380 sec/batch
# Epoch: 6/20...  Training Step: 23600...  Training loss: 1.4412...  0.0385 sec/batch
# Epoch: 6/20...  Training Step: 23650...  Training loss: 1.3252...  0.0382 sec/batch
# Epoch: 6/20...  Training Step: 23700...  Training loss: 1.4045...  0.0392 sec/batch
# Epoch: 6/20...  Training Step: 23750...  Training loss: 1.5674...  0.0380 sec/batch
# Epoch: 6/20...  Training Step: 23800...  Training loss: 1.2675...  0.0402 sec/batch
# Epoch: 7/20...  Training Step: 23850...  Training loss: 1.4038...  0.0396 sec/batch
# Epoch: 7/20...  Training Step: 23900...  Training loss: 1.3323...  0.0390 sec/batch
# Epoch: 7/20...  Training Step: 23950...  Training loss: 1.2924...  0.0391 sec/batch
# Epoch: 7/20...  Training Step: 24000...  Training loss: 1.2666...  0.0388 sec/batch
# Epoch: 7/20...  Training Step: 24050...  Training loss: 1.2878...  0.0394 sec/batch
# Epoch: 7/20...  Training Step: 24100...  Training loss: 1.4102...  0.0391 sec/batch
# Epoch: 7/20...  Training Step: 24150...  Training loss: 1.4364...  0.0385 sec/batch
# Epoch: 7/20...  Training Step: 24200...  Training loss: 1.3985...  0.0386 sec/batch
# Epoch: 7/20...  Training Step: 24250...  Training loss: 1.3652...  0.0393 sec/batch
# Epoch: 7/20...  Training Step: 24300...  Training loss: 1.4409...  0.0391 sec/batch
# Epoch: 7/20...  Training Step: 24350...  Training loss: 1.3930...  0.0392 sec/batch
# Epoch: 7/20...  Training Step: 24400...  Training loss: 1.5266...  0.0390 sec/batch
# Epoch: 7/20...  Training Step: 24450...  Training loss: 1.4835...  0.0398 sec/batch
# Epoch: 7/20...  Training Step: 24500...  Training loss: 1.4770...  0.0386 sec/batch
# Epoch: 7/20...  Training Step: 24550...  Training loss: 1.2651...  0.0384 sec/batch
# Epoch: 7/20...  Training Step: 24600...  Training loss: 1.5579...  0.0397 sec/batch
# Epoch: 7/20...  Training Step: 24650...  Training loss: 1.2542...  0.0392 sec/batch
# Epoch: 7/20...  Training Step: 24700...  Training loss: 1.2709...  0.0383 sec/batch
# Epoch: 7/20...  Training Step: 24750...  Training loss: 1.3988...  0.0396 sec/batch
# Epoch: 7/20...  Training Step: 24800...  Training loss: 1.2949...  0.0392 sec/batch
# Epoch: 7/20...  Training Step: 24850...  Training loss: 1.3696...  0.0386 sec/batch
# Epoch: 7/20...  Training Step: 24900...  Training loss: 1.2128...  0.0392 sec/batch
# Epoch: 7/20...  Training Step: 24950...  Training loss: 1.1871...  0.0390 sec/batch
# Epoch: 7/20...  Training Step: 25000...  Training loss: 1.3718...  0.0383 sec/batch
# Epoch: 7/20...  Training Step: 25050...  Training loss: 1.4365...  0.0398 sec/batch
# Epoch: 7/20...  Training Step: 25100...  Training loss: 1.2405...  0.0391 sec/batch
# Epoch: 7/20...  Training Step: 25150...  Training loss: 1.4460...  0.0390 sec/batch
# Epoch: 7/20...  Training Step: 25200...  Training loss: 1.3265...  0.0385 sec/batch
# Epoch: 7/20...  Training Step: 25250...  Training loss: 1.4910...  0.0394 sec/batch
# Epoch: 7/20...  Training Step: 25300...  Training loss: 1.3530...  0.0386 sec/batch
# Epoch: 7/20...  Training Step: 25350...  Training loss: 1.3689...  0.0386 sec/batch
# Epoch: 7/20...  Training Step: 25400...  Training loss: 1.3642...  0.0378 sec/batch
# Epoch: 7/20...  Training Step: 25450...  Training loss: 1.4982...  0.0376 sec/batch
# Epoch: 7/20...  Training Step: 25500...  Training loss: 1.3470...  0.0389 sec/batch
# Epoch: 7/20...  Training Step: 25550...  Training loss: 1.2637...  0.0386 sec/batch
# Epoch: 7/20...  Training Step: 25600...  Training loss: 1.3171...  0.0390 sec/batch
# Epoch: 7/20...  Training Step: 25650...  Training loss: 1.4600...  0.0390 sec/batch
# Epoch: 7/20...  Training Step: 25700...  Training loss: 1.4278...  0.0395 sec/batch
# Epoch: 7/20...  Training Step: 25750...  Training loss: 1.3101...  0.0385 sec/batch
# Epoch: 7/20...  Training Step: 25800...  Training loss: 1.3614...  0.0394 sec/batch
# Epoch: 7/20...  Training Step: 25850...  Training loss: 1.2880...  0.0402 sec/batch
# Epoch: 7/20...  Training Step: 25900...  Training loss: 1.3451...  0.0395 sec/batch
# Epoch: 7/20...  Training Step: 25950...  Training loss: 1.4855...  0.0377 sec/batch
# Epoch: 7/20...  Training Step: 26000...  Training loss: 1.4044...  0.0388 sec/batch
# Epoch: 7/20...  Training Step: 26050...  Training loss: 1.3959...  0.0378 sec/batch
# Epoch: 7/20...  Training Step: 26100...  Training loss: 1.3267...  0.0398 sec/batch
# Epoch: 7/20...  Training Step: 26150...  Training loss: 1.2984...  0.0385 sec/batch
# Epoch: 7/20...  Training Step: 26200...  Training loss: 1.4067...  0.0387 sec/batch
# Epoch: 7/20...  Training Step: 26250...  Training loss: 1.2673...  0.0381 sec/batch
# Epoch: 7/20...  Training Step: 26300...  Training loss: 1.3319...  0.0390 sec/batch
# Epoch: 7/20...  Training Step: 26350...  Training loss: 1.3221...  0.0390 sec/batch
# Epoch: 7/20...  Training Step: 26400...  Training loss: 1.4486...  0.0388 sec/batch
# Epoch: 7/20...  Training Step: 26450...  Training loss: 1.5697...  0.0391 sec/batch
# Epoch: 7/20...  Training Step: 26500...  Training loss: 1.3838...  0.0394 sec/batch
# Epoch: 7/20...  Training Step: 26550...  Training loss: 1.3206...  0.0391 sec/batch
# Epoch: 7/20...  Training Step: 26600...  Training loss: 1.2897...  0.0394 sec/batch
# Epoch: 7/20...  Training Step: 26650...  Training loss: 1.3807...  0.0365 sec/batch
# Epoch: 7/20...  Training Step: 26700...  Training loss: 1.3477...  0.0383 sec/batch
# Epoch: 7/20...  Training Step: 26750...  Training loss: 1.2697...  0.0385 sec/batch
# Epoch: 7/20...  Training Step: 26800...  Training loss: 1.5605...  0.0392 sec/batch
# Epoch: 7/20...  Training Step: 26850...  Training loss: 1.3090...  0.0386 sec/batch
# Epoch: 7/20...  Training Step: 26900...  Training loss: 1.3656...  0.0384 sec/batch
# Epoch: 7/20...  Training Step: 26950...  Training loss: 1.2918...  0.0392 sec/batch
# Epoch: 7/20...  Training Step: 27000...  Training loss: 1.2489...  0.0394 sec/batch
# Epoch: 7/20...  Training Step: 27050...  Training loss: 1.4329...  0.0399 sec/batch
# Epoch: 7/20...  Training Step: 27100...  Training loss: 1.3043...  0.0383 sec/batch
# Epoch: 7/20...  Training Step: 27150...  Training loss: 1.4463...  0.0396 sec/batch
# Epoch: 7/20...  Training Step: 27200...  Training loss: 1.2904...  0.0403 sec/batch
# Epoch: 7/20...  Training Step: 27250...  Training loss: 1.2156...  0.0390 sec/batch
# Epoch: 7/20...  Training Step: 27300...  Training loss: 1.1785...  0.0401 sec/batch
# Epoch: 7/20...  Training Step: 27350...  Training loss: 1.2690...  0.0412 sec/batch
# Epoch: 7/20...  Training Step: 27400...  Training loss: 1.2037...  0.0390 sec/batch
# Epoch: 7/20...  Training Step: 27450...  Training loss: 1.2973...  0.0388 sec/batch
# Epoch: 7/20...  Training Step: 27500...  Training loss: 1.6042...  0.0394 sec/batch
# Epoch: 7/20...  Training Step: 27550...  Training loss: 1.4560...  0.0390 sec/batch
# Epoch: 7/20...  Training Step: 27600...  Training loss: 1.5548...  0.0389 sec/batch
# Epoch: 7/20...  Training Step: 27650...  Training loss: 1.3406...  0.0397 sec/batch
# Epoch: 7/20...  Training Step: 27700...  Training loss: 1.3708...  0.0384 sec/batch
# Epoch: 7/20...  Training Step: 27750...  Training loss: 1.3693...  0.0402 sec/batch
# Epoch: 8/20...  Training Step: 27800...  Training loss: 1.4041...  0.0387 sec/batch
# Epoch: 8/20...  Training Step: 27850...  Training loss: 1.3601...  0.0393 sec/batch
# Epoch: 8/20...  Training Step: 27900...  Training loss: 1.3603...  0.0389 sec/batch
# Epoch: 8/20...  Training Step: 27950...  Training loss: 1.5450...  0.0391 sec/batch
# Epoch: 8/20...  Training Step: 28000...  Training loss: 1.3528...  0.0384 sec/batch
# Epoch: 8/20...  Training Step: 28050...  Training loss: 1.2795...  0.0392 sec/batch
# Epoch: 8/20...  Training Step: 28100...  Training loss: 1.4620...  0.0389 sec/batch
# Epoch: 8/20...  Training Step: 28150...  Training loss: 1.4118...  0.0404 sec/batch
# Epoch: 8/20...  Training Step: 28200...  Training loss: 1.4027...  0.0394 sec/batch
# Epoch: 8/20...  Training Step: 28250...  Training loss: 1.5483...  0.0385 sec/batch
# Epoch: 8/20...  Training Step: 28300...  Training loss: 1.4400...  0.0384 sec/batch
# Epoch: 8/20...  Training Step: 28350...  Training loss: 1.4341...  0.0384 sec/batch
# Epoch: 8/20...  Training Step: 28400...  Training loss: 1.3075...  0.0389 sec/batch
# Epoch: 8/20...  Training Step: 28450...  Training loss: 1.3478...  0.0396 sec/batch
# Epoch: 8/20...  Training Step: 28500...  Training loss: 1.4500...  0.0386 sec/batch
# Epoch: 8/20...  Training Step: 28550...  Training loss: 1.2472...  0.0394 sec/batch
# Epoch: 8/20...  Training Step: 28600...  Training loss: 1.3024...  0.0390 sec/batch
# Epoch: 8/20...  Training Step: 28650...  Training loss: 1.4683...  0.0394 sec/batch
# Epoch: 8/20...  Training Step: 28700...  Training loss: 1.4163...  0.0404 sec/batch
# ...
# Epoch: 18/20...  Training Step: 70050...  Training loss: 1.1035...  0.0390 sec/batch
# Epoch: 18/20...  Training Step: 70100...  Training loss: 1.3519...  0.0387 sec/batch
# Epoch: 18/20...  Training Step: 70150...  Training loss: 1.3245...  0.0390 sec/batch
# Epoch: 18/20...  Training Step: 70200...  Training loss: 1.2660...  0.0393 sec/batch
# Epoch: 18/20...  Training Step: 70250...  Training loss: 1.2586...  0.0392 sec/batch
# Epoch: 18/20...  Training Step: 70300...  Training loss: 1.3424...  0.0389 sec/batch
# Epoch: 18/20...  Training Step: 70350...  Training loss: 1.2647...  0.0382 sec/batch
# Epoch: 18/20...  Training Step: 70400...  Training loss: 1.3143...  0.0388 sec/batch
# Epoch: 18/20...  Training Step: 70450...  Training loss: 1.2892...  0.0405 sec/batch
# Epoch: 18/20...  Training Step: 70500...  Training loss: 1.3994...  0.0385 sec/batch
# Epoch: 18/20...  Training Step: 70550...  Training loss: 1.2337...  0.0379 sec/batch
# Epoch: 18/20...  Training Step: 70600...  Training loss: 1.2316...  0.0390 sec/batch
# Epoch: 18/20...  Training Step: 70650...  Training loss: 1.2377...  0.0389 sec/batch
# Epoch: 18/20...  Training Step: 70700...  Training loss: 1.1753...  0.0388 sec/batch
# Epoch: 18/20...  Training Step: 70750...  Training loss: 1.2087...  0.0383 sec/batch
# Epoch: 18/20...  Training Step: 70800...  Training loss: 1.3327...  0.0383 sec/batch
# Epoch: 18/20...  Training Step: 70850...  Training loss: 1.1807...  0.0438 sec/batch
# Epoch: 18/20...  Training Step: 70900...  Training loss: 1.2955...  0.0391 sec/batch
# Epoch: 18/20...  Training Step: 70950...  Training loss: 1.1610...  0.0388 sec/batch
# Epoch: 18/20...  Training Step: 71000...  Training loss: 1.2591...  0.0386 sec/batch
# Epoch: 18/20...  Training Step: 71050...  Training loss: 1.1726...  0.0390 sec/batch
# Epoch: 18/20...  Training Step: 71100...  Training loss: 1.3232...  0.0389 sec/batch
# Epoch: 18/20...  Training Step: 71150...  Training loss: 1.3540...  0.0366 sec/batch
# Epoch: 18/20...  Training Step: 71200...  Training loss: 1.2651...  0.0401 sec/batch
# Epoch: 18/20...  Training Step: 71250...  Training loss: 1.1859...  0.0389 sec/batch
# Epoch: 18/20...  Training Step: 71300...  Training loss: 1.3542...  0.0397 sec/batch
# Epoch: 18/20...  Training Step: 71350...  Training loss: 1.4149...  0.0396 sec/batch
# Epoch: 18/20...  Training Step: 71400...  Training loss: 1.6084...  0.0390 sec/batch
# Epoch: 18/20...  Training Step: 71450...  Training loss: 1.3994...  0.0400 sec/batch
# Epoch: 19/20...  Training Step: 71500...  Training loss: 1.3539...  0.0385 sec/batch
# Epoch: 19/20...  Training Step: 71550...  Training loss: 1.3255...  0.0393 sec/batch
# Epoch: 19/20...  Training Step: 71600...  Training loss: 1.2519...  0.0387 sec/batch
# Epoch: 19/20...  Training Step: 71650...  Training loss: 1.2481...  0.0384 sec/batch
# Epoch: 19/20...  Training Step: 71700...  Training loss: 1.3638...  0.0381 sec/batch
# Epoch: 19/20...  Training Step: 71750...  Training loss: 1.2367...  0.0369 sec/batch
# Epoch: 19/20...  Training Step: 71800...  Training loss: 1.3160...  0.0386 sec/batch
# Epoch: 19/20...  Training Step: 71850...  Training loss: 1.2712...  0.0381 sec/batch
# Epoch: 19/20...  Training Step: 71900...  Training loss: 1.3579...  0.0386 sec/batch
# Epoch: 19/20...  Training Step: 71950...  Training loss: 1.2874...  0.0389 sec/batch
# Epoch: 19/20...  Training Step: 72000...  Training loss: 1.1148...  0.0392 sec/batch
# Epoch: 19/20...  Training Step: 72050...  Training loss: 1.4421...  0.0383 sec/batch
# Epoch: 19/20...  Training Step: 72100...  Training loss: 1.1508...  0.0389 sec/batch
# Epoch: 19/20...  Training Step: 72150...  Training loss: 1.1987...  0.0396 sec/batch
# Epoch: 19/20...  Training Step: 72200...  Training loss: 1.2375...  0.0393 sec/batch
# Epoch: 19/20...  Training Step: 72250...  Training loss: 1.3057...  0.0398 sec/batch
# Epoch: 19/20...  Training Step: 72300...  Training loss: 1.3179...  0.0394 sec/batch
# Epoch: 19/20...  Training Step: 72350...  Training loss: 1.2784...  0.0383 sec/batch
# Epoch: 19/20...  Training Step: 72400...  Training loss: 1.2308...  0.0391 sec/batch
# Epoch: 19/20...  Training Step: 72450...  Training loss: 1.3230...  0.0390 sec/batch
# Epoch: 19/20...  Training Step: 72500...  Training loss: 1.4634...  0.0388 sec/batch
# Epoch: 19/20...  Training Step: 72550...  Training loss: 1.5297...  0.0385 sec/batch
# Epoch: 19/20...  Training Step: 72600...  Training loss: 1.4866...  0.0399 sec/batch
# Epoch: 19/20...  Training Step: 72650...  Training loss: 1.3064...  0.0385 sec/batch
# Epoch: 19/20...  Training Step: 72700...  Training loss: 1.2091...  0.0391 sec/batch
# Epoch: 19/20...  Training Step: 72750...  Training loss: 1.5109...  0.0388 sec/batch
# Epoch: 19/20...  Training Step: 72800...  Training loss: 1.3324...  0.0397 sec/batch
# Epoch: 19/20...  Training Step: 72850...  Training loss: 1.2720...  0.0391 sec/batch
# Epoch: 19/20...  Training Step: 72900...  Training loss: 1.2896...  0.0381 sec/batch
# Epoch: 19/20...  Training Step: 72950...  Training loss: 1.3844...  0.0392 sec/batch
# Epoch: 19/20...  Training Step: 73000...  Training loss: 1.3891...  0.0390 sec/batch
# Epoch: 19/20...  Training Step: 73050...  Training loss: 1.3694...  0.0391 sec/batch
# Epoch: 19/20...  Training Step: 73100...  Training loss: 1.3859...  0.0390 sec/batch
# Epoch: 19/20...  Training Step: 73150...  Training loss: 1.2341...  0.0387 sec/batch
# Epoch: 19/20...  Training Step: 73200...  Training loss: 1.3495...  0.0387 sec/batch
# Epoch: 19/20...  Training Step: 73250...  Training loss: 1.2940...  0.0394 sec/batch
# Epoch: 19/20...  Training Step: 73300...  Training loss: 1.3449...  0.0403 sec/batch
# Epoch: 19/20...  Training Step: 73350...  Training loss: 1.3443...  0.0396 sec/batch
# Epoch: 19/20...  Training Step: 73400...  Training loss: 1.5509...  0.0387 sec/batch
# Epoch: 19/20...  Training Step: 73450...  Training loss: 1.3806...  0.0389 sec/batch
# Epoch: 19/20...  Training Step: 73500...  Training loss: 1.3675...  0.0384 sec/batch
# Epoch: 19/20...  Training Step: 73550...  Training loss: 1.3243...  0.0405 sec/batch
# Epoch: 19/20...  Training Step: 73600...  Training loss: 1.3836...  0.0393 sec/batch
# Epoch: 19/20...  Training Step: 73650...  Training loss: 1.2980...  0.0384 sec/batch
# Epoch: 19/20...  Training Step: 73700...  Training loss: 1.5120...  0.0393 sec/batch
# Epoch: 19/20...  Training Step: 73750...  Training loss: 1.2655...  0.0384 sec/batch
# Epoch: 19/20...  Training Step: 73800...  Training loss: 1.4607...  0.0394 sec/batch
# Epoch: 19/20...  Training Step: 73850...  Training loss: 1.4474...  0.0393 sec/batch
# Epoch: 19/20...  Training Step: 73900...  Training loss: 1.5577...  0.0393 sec/batch
# Epoch: 19/20...  Training Step: 73950...  Training loss: 1.3544...  0.0386 sec/batch
# Epoch: 19/20...  Training Step: 74000...  Training loss: 1.3849...  0.0392 sec/batch
# Epoch: 19/20...  Training Step: 74050...  Training loss: 1.3010...  0.0385 sec/batch
# Epoch: 19/20...  Training Step: 74100...  Training loss: 1.2143...  0.0398 sec/batch
# Epoch: 19/20...  Training Step: 74150...  Training loss: 1.3782...  0.0386 sec/batch
# Epoch: 19/20...  Training Step: 74200...  Training loss: 1.2700...  0.0388 sec/batch
# Epoch: 19/20...  Training Step: 74250...  Training loss: 1.2405...  0.0380 sec/batch
# Epoch: 19/20...  Training Step: 74300...  Training loss: 1.3692...  0.0400 sec/batch
# Epoch: 19/20...  Training Step: 74350...  Training loss: 1.2250...  0.0383 sec/batch
# Epoch: 19/20...  Training Step: 74400...  Training loss: 1.3690...  0.0394 sec/batch
# Epoch: 19/20...  Training Step: 74450...  Training loss: 1.6395...  0.0403 sec/batch
# Epoch: 19/20...  Training Step: 74500...  Training loss: 1.3959...  0.0381 sec/batch
# Epoch: 19/20...  Training Step: 74550...  Training loss: 1.3211...  0.0400 sec/batch
# Epoch: 19/20...  Training Step: 74600...  Training loss: 1.3890...  0.0385 sec/batch
# Epoch: 19/20...  Training Step: 74650...  Training loss: 1.2308...  0.0383 sec/batch
# Epoch: 19/20...  Training Step: 74700...  Training loss: 1.2349...  0.0405 sec/batch
# Epoch: 19/20...  Training Step: 74750...  Training loss: 1.4845...  0.0390 sec/batch
# Epoch: 19/20...  Training Step: 74800...  Training loss: 1.3905...  0.0368 sec/batch
# Epoch: 19/20...  Training Step: 74850...  Training loss: 1.2991...  0.0366 sec/batch
# Epoch: 19/20...  Training Step: 74900...  Training loss: 1.3271...  0.0392 sec/batch
# Epoch: 19/20...  Training Step: 74950...  Training loss: 1.4758...  0.0391 sec/batch
# Epoch: 19/20...  Training Step: 75000...  Training loss: 1.2553...  0.0397 sec/batch
# Epoch: 19/20...  Training Step: 75050...  Training loss: 1.2311...  0.0386 sec/batch
# Epoch: 19/20...  Training Step: 75100...  Training loss: 1.2834...  0.0389 sec/batch
# Epoch: 19/20...  Training Step: 75150...  Training loss: 1.3477...  0.0393 sec/batch
# Epoch: 19/20...  Training Step: 75200...  Training loss: 1.2701...  0.0391 sec/batch
# Epoch: 19/20...  Training Step: 75250...  Training loss: 1.2697...  0.0390 sec/batch
# Epoch: 19/20...  Training Step: 75300...  Training loss: 1.3585...  0.0391 sec/batch
# Epoch: 19/20...  Training Step: 75350...  Training loss: 1.3157...  0.0395 sec/batch
# Epoch: 19/20...  Training Step: 75400...  Training loss: 1.3578...  0.0396 sec/batch
# Epoch: 20/20...  Training Step: 75450...  Training loss: 1.3834...  0.0396 sec/batch
# Epoch: 20/20...  Training Step: 75500...  Training loss: 1.3187...  0.0391 sec/batch
# Epoch: 20/20...  Training Step: 75550...  Training loss: 1.2493...  0.0389 sec/batch
# Epoch: 20/20...  Training Step: 75600...  Training loss: 1.3503...  0.0396 sec/batch
# Epoch: 20/20...  Training Step: 75650...  Training loss: 1.2920...  0.0399 sec/batch
# Epoch: 20/20...  Training Step: 75700...  Training loss: 1.3650...  0.0388 sec/batch
# Epoch: 20/20...  Training Step: 75750...  Training loss: 1.4119...  0.0396 sec/batch
# Epoch: 20/20...  Training Step: 75800...  Training loss: 1.3712...  0.0381 sec/batch
# Epoch: 20/20...  Training Step: 75850...  Training loss: 1.3320...  0.0404 sec/batch
# Epoch: 20/20...  Training Step: 75900...  Training loss: 1.3648...  0.0387 sec/batch
# Epoch: 20/20...  Training Step: 75950...  Training loss: 1.2527...  0.0389 sec/batch
# Epoch: 20/20...  Training Step: 76000...  Training loss: 1.4070...  0.0401 sec/batch
# Epoch: 20/20...  Training Step: 76050...  Training loss: 1.1587...  0.0387 sec/batch
# Epoch: 20/20...  Training Step: 76100...  Training loss: 1.3426...  0.0383 sec/batch
# Epoch: 20/20...  Training Step: 76150...  Training loss: 1.3126...  0.0397 sec/batch
# Epoch: 20/20...  Training Step: 76200...  Training loss: 1.2861...  0.0379 sec/batch
# Epoch: 20/20...  Training Step: 76250...  Training loss: 1.3236...  0.0389 sec/batch
# Epoch: 20/20...  Training Step: 76300...  Training loss: 1.2583...  0.0390 sec/batch
# Epoch: 20/20...  Training Step: 76350...  Training loss: 1.2355...  0.0388 sec/batch
# Epoch: 20/20...  Training Step: 76400...  Training loss: 1.2586...  0.0392 sec/batch
# Epoch: 20/20...  Training Step: 76450...  Training loss: 1.0947...  0.0390 sec/batch
# Epoch: 20/20...  Training Step: 76500...  Training loss: 1.1952...  0.0397 sec/batch
# Epoch: 20/20...  Training Step: 76550...  Training loss: 1.1297...  0.0391 sec/batch
# Epoch: 20/20...  Training Step: 76600...  Training loss: 1.2475...  0.0393 sec/batch
# Epoch: 20/20...  Training Step: 76650...  Training loss: 1.1636...  0.0383 sec/batch
# Epoch: 20/20...  Training Step: 76700...  Training loss: 1.2896...  0.0398 sec/batch
# Epoch: 20/20...  Training Step: 76750...  Training loss: 1.3773...  0.0396 sec/batch
# Epoch: 20/20...  Training Step: 76800...  Training loss: 1.3391...  0.0384 sec/batch
# Epoch: 20/20...  Training Step: 76850...  Training loss: 1.3180...  0.0398 sec/batch
# Epoch: 20/20...  Training Step: 76900...  Training loss: 1.2825...  0.0396 sec/batch
# Epoch: 20/20...  Training Step: 76950...  Training loss: 1.2683...  0.0392 sec/batch
# Epoch: 20/20...  Training Step: 77000...  Training loss: 1.3017...  0.0402 sec/batch
# Epoch: 20/20...  Training Step: 77050...  Training loss: 1.4212...  0.0389 sec/batch
# Epoch: 20/20...  Training Step: 77100...  Training loss: 1.3647...  0.0385 sec/batch
# Epoch: 20/20...  Training Step: 77150...  Training loss: 1.2589...  0.0384 sec/batch
# Epoch: 20/20...  Training Step: 77200...  Training loss: 1.3565...  0.0380 sec/batch
# Epoch: 20/20...  Training Step: 77250...  Training loss: 1.2791...  0.0371 sec/batch
# Epoch: 20/20...  Training Step: 77300...  Training loss: 1.0829...  0.0394 sec/batch
# Epoch: 20/20...  Training Step: 77350...  Training loss: 1.3241...  0.0389 sec/batch
# Epoch: 20/20...  Training Step: 77400...  Training loss: 1.3032...  0.0391 sec/batch
# Epoch: 20/20...  Training Step: 77450...  Training loss: 1.2015...  0.0399 sec/batch
# Epoch: 20/20...  Training Step: 77500...  Training loss: 1.2613...  0.0390 sec/batch
# Epoch: 20/20...  Training Step: 77550...  Training loss: 1.1018...  0.0395 sec/batch
# Epoch: 20/20...  Training Step: 77600...  Training loss: 1.2232...  0.0382 sec/batch
# Epoch: 20/20...  Training Step: 77650...  Training loss: 1.2809...  0.0388 sec/batch
# Epoch: 20/20...  Training Step: 77700...  Training loss: 1.1771...  0.0386 sec/batch
# Epoch: 20/20...  Training Step: 77750...  Training loss: 1.2609...  0.0386 sec/batch
# Epoch: 20/20...  Training Step: 77800...  Training loss: 1.2135...  0.0393 sec/batch
# Epoch: 20/20...  Training Step: 77850...  Training loss: 1.4190...  0.0369 sec/batch
# Epoch: 20/20...  Training Step: 77900...  Training loss: 1.2487...  0.0371 sec/batch
# Epoch: 20/20...  Training Step: 77950...  Training loss: 1.3916...  0.0392 sec/batch
# Epoch: 20/20...  Training Step: 78000...  Training loss: 2.1687...  0.0380 sec/batch
# Epoch: 20/20...  Training Step: 78050...  Training loss: 1.2751...  0.0385 sec/batch
# Epoch: 20/20...  Training Step: 78100...  Training loss: 1.5349...  0.0395 sec/batch
# Epoch: 20/20...  Training Step: 78150...  Training loss: 2.1773...  0.0384 sec/batch
# Epoch: 20/20...  Training Step: 78200...  Training loss: 2.1645...  0.0386 sec/batch
# Epoch: 20/20...  Training Step: 78250...  Training loss: 2.1221...  0.0394 sec/batch
# Epoch: 20/20...  Training Step: 78300...  Training loss: 1.8496...  0.0372 sec/batch
# Epoch: 20/20...  Training Step: 78350...  Training loss: 1.7867...  0.0398 sec/batch
# Epoch: 20/20...  Training Step: 78400...  Training loss: 1.6471...  0.0378 sec/batch
# Epoch: 20/20...  Training Step: 78450...  Training loss: 1.8411...  0.0370 sec/batch
# Epoch: 20/20...  Training Step: 78500...  Training loss: 1.8454...  0.0390 sec/batch
# Epoch: 20/20...  Training Step: 78550...  Training loss: 2.0233...  0.0386 sec/batch
# Epoch: 20/20...  Training Step: 78600...  Training loss: 1.7663...  0.0397 sec/batch
# Epoch: 20/20...  Training Step: 78650...  Training loss: 1.7288...  0.0395 sec/batch
# Epoch: 20/20...  Training Step: 78700...  Training loss: 1.8096...  0.0391 sec/batch
# Epoch: 20/20...  Training Step: 78750...  Training loss: 1.5847...  0.0390 sec/batch
# Epoch: 20/20...  Training Step: 78800...  Training loss: 1.7738...  0.0382 sec/batch
# Epoch: 20/20...  Training Step: 78850...  Training loss: 1.7498...  0.0382 sec/batch
# Epoch: 20/20...  Training Step: 78900...  Training loss: 1.7278...  0.0384 sec/batch
# Epoch: 20/20...  Training Step: 78950...  Training loss: 2.0906...  0.0406 sec/batch
# Epoch: 20/20...  Training Step: 79000...  Training loss: 1.6374...  0.0384 sec/batch
# Epoch: 20/20...  Training Step: 79050...  Training loss: 1.7226...  0.0388 sec/batch
# Epoch: 20/20...  Training Step: 79100...  Training loss: 1.5730...  0.0389 sec/batch
# Epoch: 20/20...  Training Step: 79150...  Training loss: 1.7124...  0.0383 sec/batch
# Epoch: 20/20...  Training Step: 79200...  Training loss: 1.6794...  0.0384 sec/batch
# Epoch: 20/20...  Training Step: 79250...  Training loss: 1.8282...  0.0392 sec/batch
# Epoch: 20/20...  Training Step: 79300...  Training loss: 1.5851...  0.0384 sec/batch
# Epoch: 20/20...  Training Step: 79350...  Training loss: 1.9670...  0.0389 sec/batch
# Epoch: 20/20...  Training Step: 79400...  Training loss: 1.7477...  0.0390 sec/batch

# %% [markdown]
# #### Saved checkpoints
#
# Read up on saving and loading checkpoints here: https://www.tensorflow.org/programmers_guide/variables

# %%
tf.train.get_checkpoint_state('checkpoints')
# Out:
# model_checkpoint_path: "checkpoints/i79400_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i59600_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i59800_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i60000_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i60200_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i60400_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i60600_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i60800_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i61000_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i61200_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i61400_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i61600_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i61800_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i62000_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i62200_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i62400_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i62600_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i62800_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i63000_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i63200_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i63400_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i63600_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i63800_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i64000_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i64200_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i64400_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i64600_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i64800_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i65000_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i65200_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i65400_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i65600_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i65800_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i66000_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i66200_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i66400_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i66600_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i66800_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i67000_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i67200_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i67400_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i67600_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i67800_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i68000_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i68200_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i68400_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i68600_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i68800_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i69000_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i69200_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i69400_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i69600_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i69800_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i70000_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i70200_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i70400_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i70600_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i70800_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i71000_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i71200_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i71400_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i71600_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i71800_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i72000_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i72200_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i72400_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i72600_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i72800_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i73000_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i73200_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i73400_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i73600_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i73800_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i74000_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i74200_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i74400_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i74600_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i74800_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i75000_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i75200_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i75400_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i75600_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i75800_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i76000_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i76200_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i76400_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i76600_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i76800_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i77000_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i77200_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i77400_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i77600_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i77800_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i78000_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i78200_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i78400_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i78600_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i78800_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i79000_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i79200_l256.ckpt"
# all_model_checkpoint_paths: "checkpoints/i79400_l256.ckpt"

# %% [markdown]
# ## Sampling
#
# Now that the network is trained, we'll can use it to generate new text. The idea is that we pass in a character, then the network will predict the next character. We can use the new one, to predict the next one. And we keep doing this to generate all new text. I also included some functionality to prime the network with some text by passing in a string and building up a state from that.
#
# The network gives us predictions for each character. To reduce noise and make things a little less random, I'm going to only choose a new character from the top N most likely characters.

# %%
def pick_top_n(preds, vocab_size, top_n=5):
    p = np.squeeze(preds)
    p[np.argsort(p)[:-top_n]] = 0
    p = p / np.sum(p)
    c = np.random.choice(vocab_size, 1, p=p)[0]
    return c

# %%
def sample(checkpoint, n_samples, lstm_size, vocab_size, prime="The "):
    samples = [c for c in prime]
    model = CharRNN(len(vocab), lstm_size=lstm_size, sampling=True)
    saver = tf.train.Saver()
    with tf.Session() as sess:
        saver.restore(sess, checkpoint)
        new_state = sess.run(model.initial_state)
        for c in prime:
            x = np.zeros((1, 1))
            x[0,0] = vocab_to_int[c]
            feed = {model.inputs: x,
                    model.keep_prob: 1.,
                    model.initial_state: new_state}
            preds, new_state = sess.run([model.prediction, model.final_state], 
                                         feed_dict=feed)

        c = pick_top_n(preds, len(vocab))
        samples.append(int_to_vocab[c])

        for i in range(n_samples):
            x[0,0] = c
            feed = {model.inputs: x,
                    model.keep_prob: 1.,
                    model.initial_state: new_state}
            preds, new_state = sess.run([model.prediction, model.final_state], 
                                         feed_dict=feed)

            c = pick_top_n(preds, len(vocab))
            samples.append(int_to_vocab[c])
        
    return ''.join(samples)

# %% [markdown]
# Here, pass in the path to a checkpoint and sample from the network.

# %%
tf.train.latest_checkpoint('checkpoints')
# Out:
# 'checkpoints/i79400_l256.ckpt'

# %%
checkpoint = tf.train.latest_checkpoint('checkpoints')
samp = sample(checkpoint, 2000, lstm_size, len(vocab), prime="Far")
print(samp)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/i79400_l256.ckpt
# Fary he had begnat to say.
# Why
# is you a servatare," said Levin and would have an hands and would not a servants was, but his happing hand of him
# him of the bother on the past the first a crows
# house without thought of that state, but. He went on of the black, to see her, and a talk and a love to see the standice, and sented he went unto the signicial, and
# he was into an horse of the stranged the stath of sher same, they carn and here was trains
# of her
# friend, and an indeed to can that to be asked in
# her arrivation and how though his fame was. Annower that seemed as a litir all of the
# servoing humiliation were so that stopping. The paral of
# the waiter was set of she was said in the maiding without saying and she wondered her far and sensing
# to the sall alone of her her to stores.
#
# "You'd always went
# on and went to my own own for her he would say it of sorted," he sat
# with him till to her same to the more to see a shall so that she had the feeling and he was
# some same woman.
#
# She would have become to the carriage, what she saw the freed of that maniculing another high sees, with a
# composeed to be steps of to charm and tea had to be it.
#
# "We've
# been stoods
# to her without his face."
#
# And
# so she stuped a sorrow and would
# seet tall, but she had the same
# and a she
# when the capover they had something to him.
#
# "Ne, that how anywhere! Worn anything, I'm some houd about a forest and
# and a monthe anything of a chuld, and I
# can be
# such any motion it are, that hourt to speak of a matter about
# it was to still and alone, while, what's himself with a caps that it would see, and that's not the most stance with
# the
# soul which haven't sat in the mother, to her all which is that it's nothing.
#
# "Tie and as that so she was to say, and
# I want there and anyone and
# the plates, and that the concitic time a compasting
# to
# say when she were to the mentions and stayed that she can't care it in it and have that was a shirt think. I don't be
# stood.
#
# She waited to at his was it of ansart in a lates and

# %%
checkpoint = 'checkpoints/i59600_l256.ckpt'
samp = sample(checkpoint, 1000, lstm_size, len(vocab), prime="Far")
print(samp)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/i59600_l256.ckpt
# Farin ought to mistake
# about this time, want to think the
# strange. There are not trying to
# be set in," annay had
# been something simply to happen him, and she came at a letter with still to be the solished stair.
#
# "It's the porter who seemed to settle her in that town, and see the position.
# There always wondered the son and he come from the work."
#
# "Now, there were this teachen what is so and is the
# mursine of her thoughts. I've a monich or was of
# alight. I'm all staring the presence, when you'll not take an own, well, what does it were all this way
# what I can tell me to the sort is never say him, I've at their finishing things, we'll so much what you know it's better than he's so a compensing mind the mistake woness, take the marst, that he's all their way the
# morning and why I dediscure that he's
# to me it was not that the still man's say was the sealing in the sort of the strength, and he was as he was so same to still a last single answer to him, but we've no more in spite of any temper

# %%
checkpoint = 'checkpoints/i600_l512.ckpt'
samp = sample(checkpoint, 1000, lstm_size, len(vocab), prime="Far")
print(samp)

# %%
checkpoint = 'checkpoints/i1200_l512.ckpt'
samp = sample(checkpoint, 1000, lstm_size, len(vocab), prime="Far")
print(samp)
